# %% [markdown]
# <h1>E-commerce via Computer Vision</h1>

# %% [markdown]
# ## Machine Learning: 2nd Level of Fine Tuning (3rd Step)

# %% [markdown]
# # Step 1: Set environment variables, re-image serverless, ephmeral instance (if Datalab not already running), imports, unpickle prior data

# %%
# ENVIRONMENT VARIABLES
PROJECT = 'hidden-layers-llc'
REGION  = 'us-east1'
BUCKET  = 'hidden-layers-llc'
MODULE = 'ai'
COMPONENT = 'images-raw'
GS = 'gs://'

# %%
# %%bash
# gcloud config set project hidden-layers-llc
# gcloud config set compute/region us-east1
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %%
# ONLY UNCOMMENT AND RUN THIS SCRIPT IF THIS IS THE 1ST NOTEBOOK OPENED IN THIS SESSION
#!bash install_dl_libs.sh

# %%
# import necessary libraries
import time
import string
import os
import csv
from copy import deepcopy
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
from numpy.random import seed
import pandas as pd
import pickle as pkl
import shutil 
from shutil import copy2
from orderedset import OrderedSet
from collections import OrderedDict
import warnings
from keras.engine import Model
from keras.layers import Input
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Dropout, Activation, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.optimizers import SGD, RMSprop, Adam
from keras.utils import np_utils 
from keras.callbacks import ModelCheckpoint
from keras.applications import VGG16
from keras.models import model_from_json, load_model
from keras.applications.vgg16 import preprocess_input, decode_predictions
import glob
# Now we need TensorFlow itself, as well same control (see Section 3.2 below) of its memory allocation
import tensorflow as tf
from tensorflow import set_random_seed
from keras.backend import clear_session
from keras.backend.tensorflow_backend import set_session
from keras import backend as K
import scipy.misc
import pydot
from random import shuffle
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
warnings.filterwarnings('ignore') # Stop warning about pandas .ix slicing, which is deprecated but most effective
# Out:
# Using TensorFlow backend.

# %%
# GLOBAL VARIABLES - MODELING
# desired data field for each image
desired_fields = ['img_no', 'manufacturer', 'description', 'retailer_sku', 'manufacturer_sku', 'img_url', 'img_name']
curr_dir = os.getcwd() # set the current directory in which this notebook resides
#seed(1)  # set numpy seed for reproducibility
#set_random_seed(2) # set TensorFlow see, also needed for reproducibility

# %%
#retrieve summaries from target site scrape
copy2('../df_pages_CLEAN_pkl.pickle', '.')
copy2('../dir_paths.pickle', '.')
copy2('../brand_dictionary_pkl.pickle', '.')
# Out:
# './brand_dictionary_pkl.pickle'

# %%
# Load the summary DataFrame to map searches on this site to correct labels
with open('df_pages_CLEAN_pkl.pickle', 'rb') as df_pp:
  df_pages = pkl.load(df_pp)

# %%
# Load the path details saved from target site scrape
with open('dir_paths.pickle', 'rb') as df_paths:
  home_dir = pkl.load(df_paths)
  project_folder = pkl.load(df_paths)
  target_site_folder = pkl.load(df_paths)
  images_folder = pkl.load(df_paths)
  images_train_folder = pkl.load(df_paths)
  images_validation_folder = pkl.load(df_paths)
  images_test_folder = pkl.load(df_paths)
  classes_list = pkl.load(df_paths)

# %%
# Load the brand_dict saved from target site scrape
with open('brand_dictionary_pkl.pickle', 'rb') as brand_dict_fid:
   brand_dict = pkl.load(brand_dict_fid)

# %%
# Load the labels_short dictionary, which tells us how many of which labels' images we need to create
with open('data_bal_penult.pickle', 'rb') as labels_short_dict:
  labels_short = pkl.load(labels_short_dict)
  img_counts = pkl.load(labels_short_dict)
  count_min = pkl.load(labels_short_dict)

# %%
# Load the mappings and meta-data persisted in the 1st ML Step (ML_model_1_final.ipynb)
with open('images_detail_pkl.pickle', 'rb') as image_details:
  dir_train_folders = pkl.load(image_details)
  dir_val_folders = pkl.load(image_details)
  df_ground_truth = pkl.load(image_details)
  img_all_idx_dict = pkl.load(image_details)
  img_train_idx_dict = pkl.load(image_details)
  img_val_idx_dict = pkl.load(image_details)
  n_classes = pkl.load(image_details)      #N.B.: This is used extensively below

# %%
# define some required constraints for VGG16 & image dataset paths
labels_list = sorted(classes_list) # Keras generates probabilities by class in alphabetical order
img_height_req, img_width_req, dim_color_channels = 224, 224, 3  # the last (3) is the RGB vector/pixel into VGG16
# paths to images dataset and its subsets
train_dir = './images/train'
validation_dir = './images/validation'
test_dir = './images/test'
top_model_weights_best = 'top_model_weights_Step2.h5'
train_class_cnt = 8 # of the 10 images sourced from other than target site/class 2 were randomly assigned to validation (val)
val_class_cnt = 2 # the 2 of the 10 images sourced from other than target site/class randomly assigned to validation (val)
train_cnt = 232 # 8 test images for each of the 29 classes/retailer_skus
val_cnt = 58 # 2 validation images for each of the 29 classes/retailer_skus
test_cnt = n_classes # 1 test image for each of the 29 classes/retailer_skus

# %% [markdown]
# # Step 2: Sequential Fine-Tuning

# %% [markdown]
# ## Step 2.1: Helper Functions for Balance of this Notebook

# %%
# define a function to convert these BGR images to RGB
def preprocess_input_BGR(x):
    x = x[:,:,::-1]  # convert BGR images to RGB (height=OK,width=OK, but reverse order of 3 color channels, from BGR to RGB)
    return x

# %%
# define a function to process a .jpg (or .jpeg) file received from a user into a tensor for prediction
def process_img_in(img_in_path): # img_in_path is the full path to the .jpg uploaded by the user
  img_height_req, img_width_req = 224, 224
  img = cv2.imread(img_in_path)
  x = deepcopy(img)
  x = cv2.resize(x,(img_height_req, img_width_req)).astype('float32')
  x = cv2.cvtColor(x, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but switch of 1st & 3rd color channels still works
  x = img_to_array(x)
  x = np.true_divide(x, 255) # scale np.array representation of img as required by VGG16
  x = np.expand_dims(x, axis=0) # TensorFlow expects 4th dim, for indices of images (i.e., a rank-4 tensor)

  return x

# %%
# define a function to return the fids of the top-5 matches in the test set to the input img
def get_top_5_matches(pred_labels_top5):
  global test_dir
  pred_fids = []
  pred_imgs = []
  for pred_label in pred_labels_top5:
    pred_fid = pred_label+'.jpg'
    pred_img = cv2.imread(os.path.join(test_dir,pred_label,pred_fid))
    pred_img = cv2.cvtColor(pred_img, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but switch of 1st & 3rd color channels still works
    pred_fids.append(pred_fid)
    pred_imgs.append(pred_img)
  
  return pred_fids, pred_imgs

# %%
# define a helper function to translate the top n prediction indices to class labels (text) for ONE image
def get_top_n_labels_1_img(top_n_idx_img, idx_to_label_dict, n=5):
  if isinstance(top_n_idx_img, np.ndarray):
    top_n_idx_img_list = top_n_idx_img.tolist()
  else:
    top_n_idx_img_list = top_n_idx_img
  pred_labels_top_n = []  # the container/list for the top n predicted labels for 1 image
  pred_labels_top_n = [idx_to_label_dict[i] for i in top_n_idx_img_list]
  
  return pred_labels_top_n

# %%
# define a function to translate the top n prediction indices to class labels (text) for ALL images
def get_top_n_labels_all(top_n_idxs_tout, idx_to_label_dict, n=5):
  pred_labels_top_n_all = [] # the list of list for predicted labels for all predictions
  for top_n_idx_row in top_n_idxs_tout:
    pred_labels_top_n = []  # the container/list for the top n predicted labels for 1 image
    pred_labels_top_n = get_n_pred_labels_1_img(top_n_idx_row, idx_to_label_dict)
    pred_labels_top_n_all.append(pred_labels_top_n)
  
  return pred_labels_top_n_all

# %%
# define a helper function to extract the indices of the top n predictions for ONE image
def get_top_n_idxs_1_img(probs_img, n=5):
  top_n_idxs = [] # the container for the indices for the top n matches for 1 image
  probs_copy = deepcopy(probs_img)
  if isinstance(probs_copy, np.ndarray):
    prob_list = probs_copy.tolist()
  else:
    prob_list = probs_copy
  probs_top_n = deepcopy(prob_list)
  probs_top_n = sorted(probs_top_n, reverse=True)[0:n]
  for prob_top_n in probs_top_n:
    prob_top_n_idx = prob_list.index(prob_top_n)
    top_n_idxs.append(prob_top_n_idx)
  
  return top_n_idxs

# %%
# define a function to extract the indices of the top n predictions for ALL predictions
def get_top_n_idxs_and_labels(prob_array, idx_to_label_dict, n=5):
  probs_all = deepcopy(prob_array)
  top_n_all_idxs = [] # list of lists, each row/sublist of which is the indices of the top n image preds for 1 image
  top_n_all_labels = [] # list of lists, each row/sublist of which is the labels of the top n image preds for 1 image
  for prob_vec_idx, prob_vec in enumerate(probs_all):
    top_n_idxs = [] # the container for those indices for the top n matches for 1 image
    top_n_labels = [] # the container for those labels for the top n matches for 1 image
    prob_vec_copy = deepcopy(probs_all[prob_vec_idx,:])
    top_n_idxs = get_top_n_idxs_1_img(prob_vec_copy, n)
    top_n_labels = get_top_n_labels_1_img(top_n_idxs, idx_to_label_dict, n)
    top_n_all_idxs.append(top_n_idxs)
    top_n_all_labels.append(top_n_labels)
  
  return top_n_all_idxs, top_n_all_labels

# %% [markdown]
# ## Part 2.3 Load a Quality Integrated Model (bn & Classification) & Then Unfreeze More Layers

# %%
# Ensure that current session is set and that seeming problems with TF non-threaded avoided
clear_session()  # https://stackoverflow.com/questions/51032845/single-thread-impacts-model-accuracy-and-loss-with-tensorflow-keras-backend
config = tf.ConfigProto(intra_op_parallelism_threads=8, inter_op_parallelism_threads=24)
# Cause TF to allocate GPU memory dynamically, hopefully obviating out-of_memory ("OOM") & other problems
# From https://github.com/keras-team/keras/issues/4161
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
                                    # (nothing gets printed in Jupyter, only if you run it standalone)
config.allow_soft_placement = True
device_count={'GPU': 8, 'CPU': 16} # Use GPU as default
sess = tf.Session(graph=tf.get_default_graph(), config=config)
set_session(sess)

# %%
model_step_prev = 'tf_serving_keras_wrenches_Step2.h5'
my_model = load_model(os.path.join('models',model_step_prev))
my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 29)                7453
# =================================================================
# Total params: 21,144,925
# Trainable params: 8,790,045
# Non-trainable params: 12,354,880
# _________________________________________________________________

# %%
# set all but final 2 layers of base/bn-extractor layers as untrainable; allow final to be trained
for layer_idx, layer in enumerate(my_model.get_layer('vgg16').layers):
  if layer_idx < 17:
    print('frozen layer: layer_idx: {} layer.name: {}'.format(layer_idx, layer.name))
    layer.trainable = False
  else:
    print('un-frozen layer: layer_idx: {} layer.name: {}'.format(layer_idx, layer.name))
    layer.trainable = True
# Out:
# frozen layer: layer_idx: 0 layer.name: input_1
# frozen layer: layer_idx: 1 layer.name: block1_conv1
# frozen layer: layer_idx: 2 layer.name: block1_conv2
# frozen layer: layer_idx: 3 layer.name: block1_pool
# frozen layer: layer_idx: 4 layer.name: block2_conv1
# frozen layer: layer_idx: 5 layer.name: block2_conv2
# frozen layer: layer_idx: 6 layer.name: block2_pool
# frozen layer: layer_idx: 7 layer.name: block3_conv1
# frozen layer: layer_idx: 8 layer.name: block3_conv2
# frozen layer: layer_idx: 9 layer.name: block3_conv3
# frozen layer: layer_idx: 10 layer.name: block3_pool
# frozen layer: layer_idx: 11 layer.name: block4_conv1
# frozen layer: layer_idx: 12 layer.name: block4_conv2
# frozen layer: layer_idx: 13 layer.name: block4_conv3
# frozen layer: layer_idx: 14 layer.name: block4_pool
# frozen layer: layer_idx: 15 layer.name: block5_conv1
# frozen layer: layer_idx: 16 layer.name: block5_conv2
# un-frozen layer: layer_idx: 17 layer.name: block5_conv3
# un-frozen layer: layer_idx: 18 layer.name: block5_pool

# %% [markdown]
# ## Step 2.3 Data Generators

# %%
# create a TRAIN set ImageDataGenerator
batch_size = 4
train_datagen = ImageDataGenerator(rescale=1. / 255, 
                                   zca_whitening=True,
                                   shear_range=0.45,
                                   zoom_range=0.45,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   preprocessing_function = preprocess_input_BGR)
  
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height_req, img_width_req),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)
# Out:
# Found 232 images belonging to 29 classes.

# %%
# create a VAL (VALIDATION) set ImageDataGenerator 
validation_datagen = ImageDataGenerator(rescale=1. / 255, preprocessing_function = preprocess_input_BGR)

validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                              target_size=(img_height_req, img_width_req),
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              shuffle=False)
# Out:
# Found 58 images belonging to 29 classes.

# %% [markdown]
# ## Step 2.4 Integrated Model - 1st Level of Fine Tuning

# %%
# set model_top's hyperparamaters
learning_rate = 1e-4
epochs = 100 # increasing epsilon (below) slows training, suggesting that more epochs should be needed
beta_one = 0.9
beta_two = 0.999
epsilon = 1.5e-3 # increasing this deterrant to division by zero adds stability to the system/model
decay_rate = learning_rate / epochs
amsgrad_bool = False
batch_size = 4

# %%
# ready the top _model for training
adam = Adam(lr=learning_rate, beta_1=beta_one, beta_2=beta_two, epsilon=epsilon, decay=decay_rate, amsgrad=amsgrad_bool)
my_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath=top_model_weights_best, verbose=1, save_best_only=True)
#execute training
history = my_model.fit_generator(train_generator,
                                 samples_per_epoch=train_cnt,
                                 epochs=epochs,
                                 validation_data=validation_generator,
                                 nb_val_samples=val_cnt,
                                 callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 12s 206ms/step - loss: 2.6974 - acc: 0.2974 - val_loss: 1.8471 - val_acc: 0.4248
#
# Epoch 00001: val_loss improved from inf to 1.84709, saving model to top_model_weights_Step2.h5
# Epoch 2/100
# 58/58 [==============================] - 9s 161ms/step - loss: 2.1900 - acc: 0.3922 - val_loss: 1.8831 - val_acc: 0.4777
#
# Epoch 00002: val_loss did not improve from 1.84709
# Epoch 3/100
# 58/58 [==============================] - 9s 160ms/step - loss: 2.3230 - acc: 0.3534 - val_loss: 1.7855 - val_acc: 0.4777
#
# Epoch 00003: val_loss improved from 1.84709 to 1.78547, saving model to top_model_weights_Step2.h5
# Epoch 4/100
# 58/58 [==============================] - 9s 161ms/step - loss: 2.0127 - acc: 0.4181 - val_loss: 1.9306 - val_acc: 0.4732
#
# Epoch 00004: val_loss did not improve from 1.78547
# Epoch 5/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.9416 - acc: 0.3966 - val_loss: 1.7394 - val_acc: 0.4688
#
# Epoch 00005: val_loss improved from 1.78547 to 1.73939, saving model to top_model_weights_Step2.h5
# Epoch 6/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.6342 - acc: 0.5000 - val_loss: 1.8064 - val_acc: 0.4777
#
# Epoch 00006: val_loss did not improve from 1.73939
# Epoch 7/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.8213 - acc: 0.4397 - val_loss: 1.8611 - val_acc: 0.5446
#
# Epoch 00007: val_loss did not improve from 1.73939
# Epoch 8/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.8132 - acc: 0.4569 - val_loss: 1.7944 - val_acc: 0.5000
#
# Epoch 00008: val_loss did not improve from 1.73939
# Epoch 9/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.6497 - acc: 0.5086 - val_loss: 1.7629 - val_acc: 0.5134
#
# Epoch 00009: val_loss did not improve from 1.73939
# Epoch 10/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.5307 - acc: 0.5388 - val_loss: 1.6782 - val_acc: 0.5536
#
# Epoch 00010: val_loss improved from 1.73939 to 1.67821, saving model to top_model_weights_Step2.h5
# Epoch 11/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.5777 - acc: 0.4957 - val_loss: 1.7323 - val_acc: 0.4866
#
# Epoch 00011: val_loss did not improve from 1.67821
# Epoch 12/100
# 58/58 [==============================] - 9s 162ms/step - loss: 1.6637 - acc: 0.4914 - val_loss: 1.6905 - val_acc: 0.5536
#
# Epoch 00012: val_loss did not improve from 1.67821
# Epoch 13/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.4795 - acc: 0.5345 - val_loss: 1.8189 - val_acc: 0.5446
#
# Epoch 00013: val_loss did not improve from 1.67821
# Epoch 14/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.2281 - acc: 0.5948 - val_loss: 1.8619 - val_acc: 0.5179
#
# Epoch 00014: val_loss did not improve from 1.67821
# Epoch 15/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.3422 - acc: 0.5905 - val_loss: 1.6979 - val_acc: 0.5446
#
# Epoch 00015: val_loss did not improve from 1.67821
# Epoch 16/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.3153 - acc: 0.6121 - val_loss: 1.7792 - val_acc: 0.5487
#
# Epoch 00016: val_loss did not improve from 1.67821
# Epoch 17/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.3280 - acc: 0.5474 - val_loss: 1.6962 - val_acc: 0.5089
#
# Epoch 00017: val_loss did not improve from 1.67821
# Epoch 18/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.2663 - acc: 0.6034 - val_loss: 1.8153 - val_acc: 0.5134
#
# Epoch 00018: val_loss did not improve from 1.67821
# Epoch 19/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.2683 - acc: 0.5862 - val_loss: 1.8702 - val_acc: 0.5089
#
# Epoch 00019: val_loss did not improve from 1.67821
# Epoch 20/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.2572 - acc: 0.5733 - val_loss: 1.8134 - val_acc: 0.5045
#
# Epoch 00020: val_loss did not improve from 1.67821
# Epoch 21/100
# 58/58 [==============================] - 9s 162ms/step - loss: 1.2331 - acc: 0.5862 - val_loss: 1.9038 - val_acc: 0.5312
#
# Epoch 00021: val_loss did not improve from 1.67821
# Epoch 22/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.0892 - acc: 0.6379 - val_loss: 1.9810 - val_acc: 0.4821
#
# Epoch 00022: val_loss did not improve from 1.67821
# Epoch 23/100
# 58/58 [==============================] - 9s 161ms/step - loss: 1.1933 - acc: 0.5819 - val_loss: 1.7949 - val_acc: 0.5177
#
# Epoch 00023: val_loss did not improve from 1.67821
# Epoch 24/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.9732 - acc: 0.6853 - val_loss: 1.9103 - val_acc: 0.4955
#
# Epoch 00024: val_loss did not improve from 1.67821
# Epoch 25/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.1924 - acc: 0.6207 - val_loss: 1.7823 - val_acc: 0.5223
#
# Epoch 00025: val_loss did not improve from 1.67821
# Epoch 26/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.1204 - acc: 0.6336 - val_loss: 1.8736 - val_acc: 0.5580
#
# Epoch 00026: val_loss did not improve from 1.67821
# Epoch 27/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.1328 - acc: 0.6595 - val_loss: 1.9244 - val_acc: 0.5580
#
# Epoch 00027: val_loss did not improve from 1.67821
# Epoch 28/100
# 58/58 [==============================] - 9s 160ms/step - loss: 1.0124 - acc: 0.6379 - val_loss: 1.8396 - val_acc: 0.5714
#
# Epoch 00028: val_loss did not improve from 1.67821
# Epoch 29/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.8639 - acc: 0.7241 - val_loss: 1.9958 - val_acc: 0.5714
#
# Epoch 00029: val_loss did not improve from 1.67821
# Epoch 30/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.9302 - acc: 0.6638 - val_loss: 1.9087 - val_acc: 0.5580
#
# Epoch 00030: val_loss did not improve from 1.67821
# Epoch 31/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.9405 - acc: 0.6681 - val_loss: 1.8896 - val_acc: 0.5000
#
# Epoch 00031: val_loss did not improve from 1.67821
# Epoch 32/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.9237 - acc: 0.6940 - val_loss: 1.7971 - val_acc: 0.6027
#
# Epoch 00032: val_loss did not improve from 1.67821
# Epoch 33/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8714 - acc: 0.7026 - val_loss: 2.0463 - val_acc: 0.5312
#
# Epoch 00033: val_loss did not improve from 1.67821
# Epoch 34/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8104 - acc: 0.7500 - val_loss: 2.1412 - val_acc: 0.5446
#
# Epoch 00034: val_loss did not improve from 1.67821
# Epoch 35/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8145 - acc: 0.7155 - val_loss: 2.0707 - val_acc: 0.5580
#
# Epoch 00035: val_loss did not improve from 1.67821
# Epoch 36/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.9283 - acc: 0.6897 - val_loss: 2.0489 - val_acc: 0.5402
#
# Epoch 00036: val_loss did not improve from 1.67821
# Epoch 37/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.7861 - acc: 0.7457 - val_loss: 2.0746 - val_acc: 0.5848
#
# Epoch 00037: val_loss did not improve from 1.67821
# Epoch 38/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.7932 - acc: 0.7241 - val_loss: 1.9608 - val_acc: 0.5354
#
# Epoch 00038: val_loss did not improve from 1.67821
# Epoch 39/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8116 - acc: 0.7328 - val_loss: 1.8879 - val_acc: 0.5625
#
# Epoch 00039: val_loss did not improve from 1.67821
# Epoch 40/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.7424 - acc: 0.7155 - val_loss: 1.8548 - val_acc: 0.5625
#
# Epoch 00040: val_loss did not improve from 1.67821
# Epoch 41/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8512 - acc: 0.6897 - val_loss: 2.0026 - val_acc: 0.5223
#
# Epoch 00041: val_loss did not improve from 1.67821
# Epoch 42/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.8119 - acc: 0.7198 - val_loss: 1.8952 - val_acc: 0.6071
#
# Epoch 00042: val_loss did not improve from 1.67821
# Epoch 43/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.7898 - acc: 0.7026 - val_loss: 1.9655 - val_acc: 0.5536
#
# Epoch 00043: val_loss did not improve from 1.67821
# Epoch 44/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.6878 - acc: 0.7586 - val_loss: 2.0329 - val_acc: 0.5357
#
# Epoch 00044: val_loss did not improve from 1.67821
# Epoch 45/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.7195 - acc: 0.7198 - val_loss: 1.9152 - val_acc: 0.5580
#
# Epoch 00045: val_loss did not improve from 1.67821
# Epoch 46/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.6424 - acc: 0.7888 - val_loss: 2.0379 - val_acc: 0.5885
#
# Epoch 00046: val_loss did not improve from 1.67821
# Epoch 47/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.6646 - acc: 0.7543 - val_loss: 1.8930 - val_acc: 0.5446
#
# Epoch 00047: val_loss did not improve from 1.67821
# Epoch 48/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.7057 - acc: 0.7198 - val_loss: 2.0717 - val_acc: 0.5848
#
# Epoch 00048: val_loss did not improve from 1.67821
# Epoch 49/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.6964 - acc: 0.7414 - val_loss: 2.1535 - val_acc: 0.5268
#
# Epoch 00049: val_loss did not improve from 1.67821
# Epoch 50/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.6679 - acc: 0.7716 - val_loss: 1.9334 - val_acc: 0.5759
#
# Epoch 00050: val_loss did not improve from 1.67821
# Epoch 51/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.7311 - acc: 0.7716 - val_loss: 2.0459 - val_acc: 0.5982
#
# Epoch 00051: val_loss did not improve from 1.67821
# Epoch 52/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.7173 - acc: 0.7629 - val_loss: 1.9872 - val_acc: 0.5446
#
# Epoch 00052: val_loss did not improve from 1.67821
# Epoch 53/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.6094 - acc: 0.7629 - val_loss: 1.9191 - val_acc: 0.5708
#
# Epoch 00053: val_loss did not improve from 1.67821
# Epoch 54/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.6384 - acc: 0.7802 - val_loss: 1.9994 - val_acc: 0.5625
#
# Epoch 00054: val_loss did not improve from 1.67821
# Epoch 55/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.6499 - acc: 0.7672 - val_loss: 2.0307 - val_acc: 0.5357
#
# Epoch 00055: val_loss did not improve from 1.67821
# Epoch 56/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5644 - acc: 0.8017 - val_loss: 2.1332 - val_acc: 0.5759
#
# Epoch 00056: val_loss did not improve from 1.67821
# Epoch 57/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.6078 - acc: 0.7888 - val_loss: 1.9584 - val_acc: 0.5893
#
# Epoch 00057: val_loss did not improve from 1.67821
# Epoch 58/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5866 - acc: 0.7716 - val_loss: 2.1440 - val_acc: 0.6071
#
# Epoch 00058: val_loss did not improve from 1.67821
# Epoch 59/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.6305 - acc: 0.7629 - val_loss: 2.0628 - val_acc: 0.5536
#
# Epoch 00059: val_loss did not improve from 1.67821
# Epoch 60/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5639 - acc: 0.7888 - val_loss: 2.1210 - val_acc: 0.5625
#
# Epoch 00060: val_loss did not improve from 1.67821
# Epoch 61/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.5212 - acc: 0.7931 - val_loss: 1.9667 - val_acc: 0.6062
#
# Epoch 00061: val_loss did not improve from 1.67821
# Epoch 62/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5413 - acc: 0.8147 - val_loss: 1.9406 - val_acc: 0.5625
#
# Epoch 00062: val_loss did not improve from 1.67821
# Epoch 63/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5655 - acc: 0.8190 - val_loss: 2.1132 - val_acc: 0.5670
#
# Epoch 00063: val_loss did not improve from 1.67821
# Epoch 64/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5151 - acc: 0.8017 - val_loss: 2.2024 - val_acc: 0.5804
#
# Epoch 00064: val_loss did not improve from 1.67821
# Epoch 65/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.6562 - acc: 0.7759 - val_loss: 2.1634 - val_acc: 0.5580
#
# Epoch 00065: val_loss did not improve from 1.67821
# Epoch 66/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.4654 - acc: 0.8319 - val_loss: 2.2013 - val_acc: 0.5625
#
# Epoch 00066: val_loss did not improve from 1.67821
# Epoch 67/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.5583 - acc: 0.8017 - val_loss: 2.2244 - val_acc: 0.4955
#
# Epoch 00067: val_loss did not improve from 1.67821
# Epoch 68/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.6032 - acc: 0.8017 - val_loss: 2.0552 - val_acc: 0.5531
#
# Epoch 00068: val_loss did not improve from 1.67821
# Epoch 69/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4506 - acc: 0.8621 - val_loss: 2.0590 - val_acc: 0.5804
#
# Epoch 00069: val_loss did not improve from 1.67821
# Epoch 70/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5830 - acc: 0.7888 - val_loss: 2.0780 - val_acc: 0.6027
#
# Epoch 00070: val_loss did not improve from 1.67821
# Epoch 71/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.4804 - acc: 0.8060 - val_loss: 2.1577 - val_acc: 0.5580
#
# Epoch 00071: val_loss did not improve from 1.67821
# Epoch 72/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5901 - acc: 0.7802 - val_loss: 2.0877 - val_acc: 0.5714
#
# Epoch 00072: val_loss did not improve from 1.67821
# Epoch 73/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5331 - acc: 0.8017 - val_loss: 1.9605 - val_acc: 0.5580
#
# Epoch 00073: val_loss did not improve from 1.67821
# Epoch 74/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.5191 - acc: 0.8017 - val_loss: 2.2641 - val_acc: 0.5357
#
# Epoch 00074: val_loss did not improve from 1.67821
# Epoch 75/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4630 - acc: 0.8190 - val_loss: 2.1328 - val_acc: 0.5268
#
# Epoch 00075: val_loss did not improve from 1.67821
# Epoch 76/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.4618 - acc: 0.8233 - val_loss: 2.1500 - val_acc: 0.5354
#
# Epoch 00076: val_loss did not improve from 1.67821
# Epoch 77/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5082 - acc: 0.7974 - val_loss: 2.0912 - val_acc: 0.5491
#
# Epoch 00077: val_loss did not improve from 1.67821
# Epoch 78/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4591 - acc: 0.8147 - val_loss: 2.1700 - val_acc: 0.5446
#
# Epoch 00078: val_loss did not improve from 1.67821
# Epoch 79/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4643 - acc: 0.8362 - val_loss: 2.2365 - val_acc: 0.5446
#
# Epoch 00079: val_loss did not improve from 1.67821
# Epoch 80/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4435 - acc: 0.8448 - val_loss: 2.1577 - val_acc: 0.5580
#
# Epoch 00080: val_loss did not improve from 1.67821
# Epoch 81/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5071 - acc: 0.8060 - val_loss: 2.2034 - val_acc: 0.5625
#
# Epoch 00081: val_loss did not improve from 1.67821
# Epoch 82/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.4312 - acc: 0.8147 - val_loss: 2.2926 - val_acc: 0.5670
#
# Epoch 00082: val_loss did not improve from 1.67821
# Epoch 83/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.5314 - acc: 0.8060 - val_loss: 2.1920 - val_acc: 0.5531
#
# Epoch 00083: val_loss did not improve from 1.67821
# Epoch 84/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4480 - acc: 0.8319 - val_loss: 2.1233 - val_acc: 0.5759
#
# Epoch 00084: val_loss did not improve from 1.67821
# Epoch 85/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.4346 - acc: 0.8233 - val_loss: 2.1624 - val_acc: 0.5938
#
# Epoch 00085: val_loss did not improve from 1.67821
# Epoch 86/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.3743 - acc: 0.8707 - val_loss: 2.2741 - val_acc: 0.5759
#
# Epoch 00086: val_loss did not improve from 1.67821
# Epoch 87/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4633 - acc: 0.8362 - val_loss: 2.2040 - val_acc: 0.5714
#
# Epoch 00087: val_loss did not improve from 1.67821
# Epoch 88/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4306 - acc: 0.8448 - val_loss: 2.1630 - val_acc: 0.6295
#
# Epoch 00088: val_loss did not improve from 1.67821
# Epoch 89/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.4360 - acc: 0.8233 - val_loss: 2.4169 - val_acc: 0.5179
#
# Epoch 00089: val_loss did not improve from 1.67821
# Epoch 90/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4816 - acc: 0.8103 - val_loss: 2.1976 - val_acc: 0.6116
#
# Epoch 00090: val_loss did not improve from 1.67821
# Epoch 91/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4279 - acc: 0.8233 - val_loss: 2.2532 - val_acc: 0.5885
#
# Epoch 00091: val_loss did not improve from 1.67821
# Epoch 92/100
# 58/58 [==============================] - 9s 162ms/step - loss: 0.3680 - acc: 0.8362 - val_loss: 2.2743 - val_acc: 0.5625
#
# Epoch 00092: val_loss did not improve from 1.67821
# Epoch 93/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4598 - acc: 0.8362 - val_loss: 2.2148 - val_acc: 0.5491
#
# Epoch 00093: val_loss did not improve from 1.67821
# Epoch 94/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4140 - acc: 0.8534 - val_loss: 2.3817 - val_acc: 0.5625
#
# Epoch 00094: val_loss did not improve from 1.67821
# Epoch 95/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4188 - acc: 0.8405 - val_loss: 2.2413 - val_acc: 0.5580
#
# Epoch 00095: val_loss did not improve from 1.67821
# Epoch 96/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.4239 - acc: 0.8578 - val_loss: 2.3572 - val_acc: 0.5446
#
# Epoch 00096: val_loss did not improve from 1.67821
# Epoch 97/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.3361 - acc: 0.8750 - val_loss: 2.3600 - val_acc: 0.5625
#
# Epoch 00097: val_loss did not improve from 1.67821
# Epoch 98/100
# 58/58 [==============================] - 9s 161ms/step - loss: 0.3943 - acc: 0.8448 - val_loss: 2.2687 - val_acc: 0.5531
#
# Epoch 00098: val_loss did not improve from 1.67821
# Epoch 99/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.3387 - acc: 0.8534 - val_loss: 2.2792 - val_acc: 0.5804
#
# Epoch 00099: val_loss did not improve from 1.67821
# Epoch 100/100
# 58/58 [==============================] - 9s 160ms/step - loss: 0.2866 - acc: 0.8966 - val_loss: 2.3353 - val_acc: 0.5893
#
# Epoch 00100: val_loss did not improve from 1.67821

# %%
(eval_loss, eval_accuracy) = my_model.evaluate_generator(train_generator,train_cnt)

# %%
# Print most common usual results
train_accuracy = history.history['acc'][-1]
train_loss = history.history['loss'][-1]
print('The ultimate TRAINING Accuracy was {:.4f}%'.format(train_accuracy * 100))
print('The ultimate EVALUATION Accuracy was {:.4f}%'.format(eval_accuracy * 100))
print('The ultimate TRAINING Loss was {}'.format(train_loss))
print('The ultimate EVALUATION Loss was {}'.format(eval_loss))

# Graph the results
plt.clf()
graph_cnt = 2

# Total Graph size and Top Title
plt.figure(figsize=(16,8))
plt.suptitle('Summary of Accuracy and Model Loss Over Epoch', fontsize=30, weight='bold')
# Build Graph Contents
training_metrics = [history.history['acc'], history.history['loss']]
validation_metrics = [history.history['val_acc'], history.history['val_loss']]
horizontal_titles = ['model accuracy', 'model loss']
vertical_axis_labels = ['accuracy', 'loss']
# Build the graph contents
for i in range(graph_cnt):
    plt.subplot(121 + (i))
    plt.plot(training_metrics[i], color='green')
    plt.plot(validation_metrics[i], color='red')
    plt.title(horizontal_titles[i])
    plt.ylabel(vertical_axis_labels[i])
    plt.xlabel('epoch')
    plt.legend(['training', 'testing'], loc='best', prop={'size': 25})

plt.show()
plt.savefig('my_model_Step3.png')
# Out:
# The ultimate TRAINING Accuracy was 89.6552%
# The ultimate EVALUATION Accuracy was 91.9181%
# The ultimate TRAINING Loss was 0.28656316099232787
# The ultimate EVALUATION Loss was 0.2039299538054138

# %%
# persist integrated model (architecture)
model_integrated_json = my_model.to_json()
with open("my_model_Step3.json", "w") as json_file:
    json_file.write(model_integrated_json)

# %%
# persist model_top (graph of weights)
my_model.save_weights("my_model_weights_Step3.h5")

# %%
# reload the same model_top architecture from this architecture
with open('my_model_Step3.json', 'r') as model_json:
  json_file = model_json.read()
my_model = model_from_json(json_file)

# %%
# load weights from best trial with some stochasticitty/volatility over a handful of trials (v4 better results)
my_model.load_weights(top_model_weights_best)    # THIS SHOULD BE CHANGED BACK TO "model_flatten_weights.h5"

# %%
model_name = "tf_serving_keras_wrenches_Step3.h5"
my_model.save(os.path.join('models',model_name))

# %%
# compile that model with the same parameters used to build it (above)
my_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Part 2.3.1 Let's show how the model performed, looking at the accuracy of predictions of the training set as validated by the validation set

# %%
# # First obtain the predictions & related data from the weighted graph generated with the VGG16 topped model
prediction_probs_val = my_model.predict_generator(validation_generator)
fids_ground_truth_val = validation_generator.filenames
label_to_idx_val_dict =  validation_generator.class_indices
idx_to_label_val_dict = dict((label, idx) for idx, label in label_to_idx_val_dict.items())

# %%
# Calculate the top-1 accuracy rate inputs
top_1_idxs_val_todos, top_1_labels_val_todos = get_top_n_idxs_and_labels(prediction_probs_val, idx_to_label_val_dict, 1)

# %%
# calculate the 1% accuracy rate in light of non-read files (both validation and train)
i = 0
error_count_1_val = 0

#fid_ground_truth_prior = fids_ground_truth_val[0].split('/')[0]
for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_val):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label != top_1_labels_val_todos[i][0]:
      print('ERROR: fid_truth_label: {} & top_1_labels_val_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_val_todos[i][0]))
      error_count_1_val += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_1_labels_val_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_val_todos[i][0]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-1 val errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_1_val, i, (1 - (error_count_1_val)/i)*100))
# Out:
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# ERROR: fid_truth_label: IRW_BM2078608 & top_1_labels_val_todos[i][0]: IRW_BM2078606
# CORRECT: fid_truth_label: IRW_BM2078608 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078612 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078612 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_val_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_val_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_val_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_val_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_val_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_val_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_val_todos[i][0]: PTY_FA-113-8TAVSE
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_val_todos[i][0]: PTY_FA-113-8TAVSE
# ERROR: fid_truth_label: PTY_J708L & top_1_labels_val_todos[i][0]: PTY_J715S
# CORRECT: fid_truth_label: PTY_J708L & top_1_labels_val_todos[i][0]: PTY_J708L
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J712S & top_1_labels_val_todos[i][0]: PTY_J715S
# CORRECT: fid_truth_label: PTY_J712S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_val_todos[i][0]: IRW_BM2078606
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: RTC_86907 & top_1_labels_val_todos[i][0]: SNY_87-367
# CORRECT: fid_truth_label: RTC_86907 & top_1_labels_val_todos[i][0]: RTC_86907
# ERROR: fid_truth_label: RTC_86917 & top_1_labels_val_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: RTC_86917 & top_1_labels_val_todos[i][0]: RTC_86917
# CORRECT: fid_truth_label: RTC_86922 & top_1_labels_val_todos[i][0]: RTC_86922
# ERROR: fid_truth_label: RTC_86922 & top_1_labels_val_todos[i][0]: RTC_86927
# ERROR: fid_truth_label: RTC_86927 & top_1_labels_val_todos[i][0]: RTC_86922
# CORRECT: fid_truth_label: RTC_86927 & top_1_labels_val_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_val_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_val_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_val_todos[i][0]: SBD_J795S
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_val_todos[i][0]: SBD_J795S
# ERROR: fid_truth_label: SNY_85-610 & top_1_labels_val_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: SNY_85-610 & top_1_labels_val_todos[i][0]: SNY_85-610
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_val_todos[i][0]: SNY_85-762
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_val_todos[i][0]: SNY_85-762
# CORRECT: fid_truth_label: SNY_87-367 & top_1_labels_val_todos[i][0]: SNY_87-367
# CORRECT: fid_truth_label: SNY_87-367 & top_1_labels_val_todos[i][0]: SNY_87-367
# CORRECT: fid_truth_label: SNY_87-369 & top_1_labels_val_todos[i][0]: SNY_87-369
# ERROR: fid_truth_label: SNY_87-369 & top_1_labels_val_todos[i][0]: SNY_87-367
# CORRECT: fid_truth_label: SNY_87-471 & top_1_labels_val_todos[i][0]: SNY_87-471
# ERROR: fid_truth_label: SNY_87-471 & top_1_labels_val_todos[i][0]: SNY_85-762
# ERROR: fid_truth_label: SNY_87-473 & top_1_labels_val_todos[i][0]: SNY_87-367
# ERROR: fid_truth_label: SNY_87-473 & top_1_labels_val_todos[i][0]: SNY_87-367
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_val_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_val_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-949 & top_1_labels_val_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-949 & top_1_labels_val_todos[i][0]: SNY_90-950
# CORRECT: fid_truth_label: SNY_90-950 & top_1_labels_val_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-950 & top_1_labels_val_todos[i][0]: SNY_90-948
# ERROR: fid_truth_label: URR_708S & top_1_labels_val_todos[i][0]: PTY_J712S
# CORRECT: fid_truth_label: URR_708S & top_1_labels_val_todos[i][0]: URR_708S
# CORRECT: fid_truth_label: URR_795G & top_1_labels_val_todos[i][0]: URR_795G
# CORRECT: fid_truth_label: URR_795G & top_1_labels_val_todos[i][0]: URR_795G
#
# ____________________________ FINAL RESULTS_____________________
# top-1 val errors: 26 wrong out of 58 predictions, or 55.1724% accuracy

# %%
# calculate the top-5 accuracy rate inputs
top_5_idxs_val_todos, top_5_labels_val_todos = get_top_n_idxs_and_labels(prediction_probs_val, idx_to_label_val_dict, 5)

# %%
# calculate the 5% accuracy rate in light of non-read files (both validation and test)
i = 0
error_count_5_val = 0

#fid_ground_truth_prior = fids_ground_truth_val[0].split('/')[0]
for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_val):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label not in top_5_labels_val_todos[i]:
      print('ERROR: fid_truth_label: {} & top_5_labels_val_todos[i]: {}'.format(fid_truth_label, top_5_labels_val_todos[i]))
      error_count_5_val += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_5_labels_val_todos[i]: {}'.format(fid_truth_label, top_5_labels_val_todos[i]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-5 val errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_5_val, i, (1 - (error_count_5_val)/i)*100))
# Out:
# CORRECT: fid_truth_label: IRW_BM2078606 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078606 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078606', 'IRW_BM2078608', 'IRW_BM2078700', 'SNY_90-950']
# ERROR: fid_truth_label: IRW_BM2078608 & top_5_labels_val_todos[i]: ['IRW_BM2078606', 'IRW_BM2078706', 'SNY_87-369', 'IRW_BM2078700', 'IRW_BM2078612']
# CORRECT: fid_truth_label: IRW_BM2078608 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078610 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078610', 'IRW_BM2078606', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078610 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078610', 'IRW_BM2078606', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078606', 'IRW_BM2078608', 'IRW_BM2078610', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078610', 'IRW_BM2078606', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_val_todos[i]: ['IRW_BM2078700', 'SNY_90-950', 'IRW_BM2078612', 'SNY_90-949', 'IRW_BM2078610']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_val_todos[i]: ['IRW_BM2078700', 'SNY_90-950', 'IRW_BM2078612', 'SNY_90-949', 'IRW_BM2078610']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_val_todos[i]: ['IRW_BM2078706', 'IRW_BM2078700', 'SNY_85-762', 'SBD_J795G', 'SNY_87-369']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_val_todos[i]: ['IRW_BM2078706', 'IRW_BM2078700', 'SNY_85-762', 'SNY_87-369', 'SBD_J795G']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_val_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86922', 'RTC_86907', 'SNY_85-762']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_val_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86922', 'RTC_86907', 'URR_708S']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_val_todos[i]: ['PTY_FA-113-8TAVSE', 'SBD_J795G', 'URR_795G', 'PTY_J708S', 'SBD_J795S']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_val_todos[i]: ['PTY_FA-113-8TAVSE', 'SBD_J795G', 'IRW_BM2078706', 'SNY_85-762', 'SBD_J795S']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_val_todos[i]: ['PTY_J715S', 'PTY_J708S', 'PTY_J708L', 'PTY_J712S', 'RTC_86917']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_val_todos[i]: ['PTY_J708L', 'SNY_87-367', 'RTC_86917', 'SNY_87-473', 'PTY_J715S']
# CORRECT: fid_truth_label: PTY_J708S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708S', 'PTY_J708L', 'RTC_86922', 'SNY_87-473']
# CORRECT: fid_truth_label: PTY_J708S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708S', 'SNY_87-473', 'URR_708S', 'PTY_J708L']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_val_todos[i]: ['PTY_J715S', 'PTY_J712S', 'PTY_J708S', 'PTY_J708L', 'SNY_87-473']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708L', 'PTY_J715S', 'PTY_J708S', 'SNY_87-473']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_val_todos[i]: ['IRW_BM2078606', 'SNY_87-471', 'IRW_BM2078612', 'PTY_J708S', 'PTY_J715S']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708L', 'PTY_J715S', 'PTY_J708S', 'SNY_87-473']
# ERROR: fid_truth_label: RTC_86907 & top_5_labels_val_todos[i]: ['SNY_87-367', 'PTY_J708L', 'SNY_87-473', 'RTC_86917', 'RTC_86927']
# CORRECT: fid_truth_label: RTC_86907 & top_5_labels_val_todos[i]: ['RTC_86907', 'SNY_87-473', 'RTC_86927', 'RTC_86922', 'RTC_86917']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86922', 'RTC_86917', 'RTC_86907', 'PTY_J708L']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_val_todos[i]: ['RTC_86917', 'RTC_86927', 'PTY_J708L', 'RTC_86922', 'RTC_86907']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_val_todos[i]: ['RTC_86922', 'RTC_86927', 'URR_708S', 'PTY_J708S', 'SNY_87-471']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86922', 'RTC_86917', 'RTC_86907', 'SNY_87-367']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_val_todos[i]: ['RTC_86922', 'RTC_86927', 'RTC_86907', 'RTC_86917', 'PTY_J708S']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86922', 'RTC_86917', 'RTC_86907', 'PTY_J708L']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_val_todos[i]: ['SBD_J795G', 'SBD_J795S', 'URR_795G', 'PTY_FA-113-8TAVSE', 'IRW_BM2078700']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_val_todos[i]: ['SBD_J795G', 'URR_795G', 'SBD_J795S', 'PTY_FA-113-8TAVSE', 'IRW_BM2078700']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_val_todos[i]: ['SBD_J795S', 'SBD_J795G', 'IRW_BM2078700', 'IRW_BM2078706', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_val_todos[i]: ['SBD_J795S', 'SBD_J795G', 'IRW_BM2078700', 'IRW_BM2078706', 'PTY_FA-113-8TAVSE']
# ERROR: fid_truth_label: SNY_85-610 & top_5_labels_val_todos[i]: ['IRW_BM2078706', 'SNY_87-473', 'SNY_85-762', 'SNY_87-369', 'URR_795G']
# CORRECT: fid_truth_label: SNY_85-610 & top_5_labels_val_todos[i]: ['SNY_85-610', 'RTC_86922', 'RTC_86927', 'PTY_J708S', 'URR_708S']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_val_todos[i]: ['SNY_85-762', 'SBD_J795G', 'SNY_87-367', 'URR_795G', 'SNY_87-369']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_val_todos[i]: ['SNY_85-762', 'URR_795G', 'SBD_J795G', 'SNY_87-367', 'IRW_BM2078700']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_val_todos[i]: ['SNY_87-367', 'PTY_J708L', 'SNY_87-369', 'SNY_87-471', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_val_todos[i]: ['SNY_87-367', 'PTY_J708L', 'SNY_87-473', 'PTY_J712S', 'SNY_87-369']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_val_todos[i]: ['SNY_87-369', 'SNY_87-473', 'SNY_87-471', 'PTY_J715S', 'PTY_J712S']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_val_todos[i]: ['SNY_87-367', 'PTY_J708L', 'SNY_87-369', 'PTY_J715S', 'SNY_87-471']
# CORRECT: fid_truth_label: SNY_87-471 & top_5_labels_val_todos[i]: ['SNY_87-471', 'SNY_87-473', 'PTY_J715S', 'PTY_J712S', 'SNY_87-369']
# CORRECT: fid_truth_label: SNY_87-471 & top_5_labels_val_todos[i]: ['SNY_85-762', 'SNY_87-473', 'SNY_87-369', 'IRW_BM2078706', 'SNY_87-471']
# ERROR: fid_truth_label: SNY_87-473 & top_5_labels_val_todos[i]: ['SNY_87-367', 'SNY_87-369', 'PTY_J708L', 'SNY_87-471', 'PTY_J715S']
# ERROR: fid_truth_label: SNY_87-473 & top_5_labels_val_todos[i]: ['SNY_87-367', 'SNY_87-369', 'SNY_87-471', 'PTY_J708L', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'IRW_BM2078612', 'IRW_BM2078610']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'IRW_BM2078612', 'IRW_BM2078610']
# CORRECT: fid_truth_label: SNY_90-949 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'RTC_86922', 'URR_708S']
# CORRECT: fid_truth_label: SNY_90-949 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'IRW_BM2078612', 'IRW_BM2078606']
# CORRECT: fid_truth_label: SNY_90-950 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'URR_708S', 'RTC_86922']
# CORRECT: fid_truth_label: SNY_90-950 & top_5_labels_val_todos[i]: ['SNY_90-948', 'SNY_90-949', 'SNY_90-950', 'IRW_BM2078608', 'IRW_BM2078610']
# ERROR: fid_truth_label: URR_708S & top_5_labels_val_todos[i]: ['PTY_J712S', 'SNY_87-471', 'PTY_J715S', 'PTY_J708S', 'SNY_87-473']
# CORRECT: fid_truth_label: URR_708S & top_5_labels_val_todos[i]: ['URR_708S', 'PTY_J715S', 'IRW_BM2078606', 'PTY_J708S', 'RTC_86922']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_val_todos[i]: ['URR_795G', 'SNY_90-950', 'IRW_BM2078706', 'SNY_85-762', 'IRW_BM2078606']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_val_todos[i]: ['URR_795G', 'SNY_90-950', 'IRW_BM2078706', 'SNY_85-762', 'IRW_BM2078606']
#
# ____________________________ FINAL RESULTS_____________________
# top-5 val errors: 6 wrong out of 58 predictions, or 89.6552% accuracy

# %% [markdown]
# ### Part 2.3.2 Evaluate the New Fully-Connected Model on test Images

# %%
# reload the same integrated model architecture
with open('my_model_Step3.json', 'r') as model_json:
  json_file = model_json.read()
my_model = model_from_json(json_file)

# %%
# load weights from best trial with some stochasticitty/volatility over a handful of trials (v4 better results)
my_model.load_weights(top_model_weights_best)    # THIS SHOULD BE CHANGED BACK TO "model_flatten_weights.h5"

# %%
# compile that model with the same parameters used to build it (above)
my_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# create an ImageDataGenerator to read the test images in from images/test
batch_size = 29
test_features = np.zeros(shape=(test_cnt, 7, 7, 512))
test_labels = np.zeros(shape=(test_cnt,n_classes))

test_datagen = ImageDataGenerator(rescale=1. / 255,
                                        #zca_whitening=True,
                                        #shear_range=0.2,
                                        #zoom_range=0.2,
                                        #horizontal_flip=True,
                                        preprocessing_function = preprocess_input_BGR)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height_req, img_width_req),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 29 images belonging to 29 classes.

# %%
#evaluate my_model against test set
(test_loss, test_accuracy) = my_model.evaluate_generator(generator=test_generator,
                              steps=batch_size,
                              verbose=1)
# Out:
# 29/29 [==============================] - 10s 351ms/step

# %%
print('The ultimate TESTING Accuracy was {:.4f}%'.format(test_accuracy * 100))
print('The ultimate TESTING Loss was {}'.format(test_loss))
# Out:
# The ultimate TESTING Accuracy was 65.5172%
# The ultimate TESTING Loss was 1.180265188217163

# %%
# # First obtain the predictions & related data from the weighted graph generated with the VGG16 topped model
prediction_probs_test = my_model.predict_generator(test_generator)
fids_ground_truth_test = test_generator.filenames
label_to_idx_test_dict =  test_generator.class_indices
idx_to_label_test_dict = dict((label, idx) for idx, label in label_to_idx_test_dict.items())

# %%
# Calculate the top-1 accuracy rate inputs
top_1_idxs_test_todos, top_1_labels_test_todos = get_top_n_idxs_and_labels(prediction_probs_test, idx_to_label_test_dict, 1)

# %%
# calculate the 1% accuracy rate in light of non-read files (test only)
i = 0
error_count_1_test = 0

for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_test):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label != top_1_labels_test_todos[i][0]:
      print('ERROR: fid_truth_label: {} & top_1_labels_test_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_test_todos[i][0]))
      error_count_1_test += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_1_labels_test_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_test_todos[i][0]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-1 test errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_1_test, i, (1 - (error_count_1_test)/i)*100))
# Out:
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_test_todos[i][0]: IRW_BM2078612
# ERROR: fid_truth_label: IRW_BM2078608 & top_1_labels_test_todos[i][0]: IRW_BM2078612
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_test_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078612 & top_1_labels_test_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_test_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_test_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_test_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_test_todos[i][0]: PTY_FA-113-8TAVSE
# CORRECT: fid_truth_label: PTY_J708L & top_1_labels_test_todos[i][0]: PTY_J708L
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_test_todos[i][0]: PTY_J712S
# CORRECT: fid_truth_label: PTY_J712S & top_1_labels_test_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_test_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: RTC_86907 & top_1_labels_test_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: RTC_86917 & top_1_labels_test_todos[i][0]: RTC_86917
# CORRECT: fid_truth_label: RTC_86922 & top_1_labels_test_todos[i][0]: RTC_86922
# CORRECT: fid_truth_label: RTC_86927 & top_1_labels_test_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_test_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_test_todos[i][0]: SBD_J795S
# CORRECT: fid_truth_label: SNY_85-610 & top_1_labels_test_todos[i][0]: SNY_85-610
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_test_todos[i][0]: SNY_85-762
# CORRECT: fid_truth_label: SNY_87-367 & top_1_labels_test_todos[i][0]: SNY_87-367
# ERROR: fid_truth_label: SNY_87-369 & top_1_labels_test_todos[i][0]: SNY_87-367
# ERROR: fid_truth_label: SNY_87-471 & top_1_labels_test_todos[i][0]: SNY_87-473
# CORRECT: fid_truth_label: SNY_87-473 & top_1_labels_test_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_test_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-949 & top_1_labels_test_todos[i][0]: SNY_90-950
# CORRECT: fid_truth_label: SNY_90-950 & top_1_labels_test_todos[i][0]: SNY_90-950
# CORRECT: fid_truth_label: URR_708S & top_1_labels_test_todos[i][0]: URR_708S
# CORRECT: fid_truth_label: URR_795G & top_1_labels_test_todos[i][0]: URR_795G
#
# ____________________________ FINAL RESULTS_____________________
# top-1 test errors: 10 wrong out of 29 predictions, or 65.5172% accuracy

# %%
# calculate the top-5 accuracy rate inputs
top_5_idxs_test_todos, top_5_labels_test_todos = get_top_n_idxs_and_labels(prediction_probs_test, idx_to_label_test_dict, 5)

# %%
# calculate the 5% accuracy rate in light of non-read files (test only)
i = 0
error_count_5_test = 0

for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_test):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label not in top_5_labels_test_todos[i]:
      print('ERROR: fid_truth_label: {} & top_5_labels_test_todos[i]: {}'.format(fid_truth_label, top_5_labels_test_todos[i]))
      error_count_5_test += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_5_labels_test_todos[i]: {}'.format(fid_truth_label, top_5_labels_test_todos[i]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-5 test errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_5_test, i, (1 - (error_count_5_test)/i)*100))
# Out:
# CORRECT: fid_truth_label: IRW_BM2078606 & top_5_labels_test_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078606', 'SNY_90-949', 'SNY_90-950']
# CORRECT: fid_truth_label: IRW_BM2078608 & top_5_labels_test_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078606', 'SNY_90-949', 'SNY_90-950']
# ERROR: fid_truth_label: IRW_BM2078610 & top_5_labels_test_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078606', 'SNY_90-949', 'SNY_90-950']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_test_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'IRW_BM2078606', 'SNY_90-949', 'SNY_90-950']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_test_todos[i]: ['IRW_BM2078700', 'IRW_BM2078706', 'IRW_BM2078612', 'SNY_90-950', 'IRW_BM2078606']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_test_todos[i]: ['IRW_BM2078706', 'IRW_BM2078700', 'SNY_85-762', 'SBD_J795G', 'SNY_87-369']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_test_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86922', 'RTC_86907', 'URR_708S']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_test_todos[i]: ['PTY_FA-113-8TAVSE', 'SBD_J795G', 'IRW_BM2078706', 'URR_795G', 'SBD_J795S']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_test_todos[i]: ['PTY_J708L', 'RTC_86917', 'SNY_87-473', 'SNY_87-367', 'RTC_86927']
# CORRECT: fid_truth_label: PTY_J708S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J708S', 'PTY_J715S', 'URR_708S', 'PTY_J708L']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J708S', 'PTY_J715S', 'URR_708S', 'PTY_J708L']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J708S', 'PTY_J715S', 'URR_708S', 'PTY_J708L']
# CORRECT: fid_truth_label: RTC_86907 & top_5_labels_test_todos[i]: ['RTC_86927', 'RTC_86917', 'RTC_86907', 'RTC_86922', 'PTY_J708L']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_test_todos[i]: ['RTC_86917', 'RTC_86927', 'PTY_J708L', 'RTC_86922', 'SNY_87-473']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_test_todos[i]: ['RTC_86922', 'RTC_86927', 'RTC_86907', 'RTC_86917', 'PTY_J708S']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_test_todos[i]: ['RTC_86927', 'RTC_86922', 'RTC_86917', 'RTC_86907', 'PTY_J708L']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_test_todos[i]: ['SBD_J795G', 'SBD_J795S', 'URR_795G', 'PTY_FA-113-8TAVSE', 'IRW_BM2078700']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_test_todos[i]: ['SBD_J795S', 'SBD_J795G', 'IRW_BM2078700', 'PTY_FA-113-8TAVSE', 'IRW_BM2078706']
# CORRECT: fid_truth_label: SNY_85-610 & top_5_labels_test_todos[i]: ['SNY_85-610', 'RTC_86927', 'RTC_86922', 'PTY_J708S', 'URR_708S']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_test_todos[i]: ['SNY_85-762', 'KTI_3239', 'SBD_J795G', 'IRW_BM2078606', 'RTC_86927']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_test_todos[i]: ['SNY_87-367', 'PTY_J708L', 'SNY_87-369', 'SNY_87-471', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_test_todos[i]: ['SNY_87-367', 'PTY_J712S', 'SNY_87-369', 'PTY_J715S', 'SNY_87-473']
# ERROR: fid_truth_label: SNY_87-471 & top_5_labels_test_todos[i]: ['SNY_87-473', 'PTY_J708L', 'SNY_87-367', 'RTC_86917', 'RTC_86927']
# CORRECT: fid_truth_label: SNY_87-473 & top_5_labels_test_todos[i]: ['SNY_87-473', 'SNY_87-369', 'SNY_87-471', 'PTY_J715S', 'PTY_J712S']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_test_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'IRW_BM2078612', 'IRW_BM2078610']
# CORRECT: fid_truth_label: SNY_90-949 & top_5_labels_test_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'URR_708S', 'RTC_86922']
# CORRECT: fid_truth_label: SNY_90-950 & top_5_labels_test_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'IRW_BM2078612', 'RTC_86922']
# CORRECT: fid_truth_label: URR_708S & top_5_labels_test_todos[i]: ['URR_708S', 'PTY_J712S', 'PTY_J708S', 'RTC_86922', 'PTY_J715S']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_test_todos[i]: ['URR_795G', 'SNY_90-950', 'IRW_BM2078706', 'IRW_BM2078700', 'IRW_BM2078606']
#
# ____________________________ FINAL RESULTS_____________________
# top-5 test errors: 2 wrong out of 29 predictions, or 93.1034% accuracy

# %% [markdown]
# ### Part 2.4 Test img input and return of top-5 best predictions

# %%
# choose, get, and view the image
fids_in = [fid for fid in os.listdir('.') if fid.endswith('.jpg')]
fids_sample = fids_in[0:9] 
imgs_sample = []
for fid in fids_sample:
  img = cv2.imread(fid)
  img = cv2.cv2.cvtColor(img, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but 1st & 3rd channel swap works 
  imgs_sample.append(img)

# %%
# Let's pick the 1st 9 sample images from this dir to view
plt.clf()
sample_cnt = 9
images_sample = imgs_sample
images_fids = fids_sample
plt.figure(figsize=(20,20))
plt.suptitle('The 1st 9 Sampled Images for This Dir in RGB', fontsize=30, weight='bold')

for i in range(sample_cnt):
    plt.subplot(331 + (i))
    plt.title(images_fids[i])
    plt.xticks([])
    plt.yticks([])   
    plt.imshow(imgs_sample[i])

plt.show()

# %%
# ready the image as a processable, predictable tensor
fid_in = fids_sample[2]
img_tensor = process_img_in(fid_in)

# %%
# get top-5 predictions
pred_probs = my_model.predict(img_tensor)
top_5_idxs, top_5_labels = get_top_n_idxs_and_labels(pred_probs, idx_to_label_test_dict, 5)
pred_labels_top5 = top_5_labels[0]
top_5_fids, top_5_imgs = get_top_5_matches(pred_labels_top5)

# %%
# Let's Look at those top-5 matches (hopefully)
plt.clf()
sample_cnt = 5
images_sample = top_5_imgs
images_fids = top_5_fids
# For each of the above pictures find the face bounding box
plt.figure(figsize=(20,20))
plt.suptitle('The Top-5 Matches for {}'.format(fid_in), fontsize=30, weight='bold')

for i in range(sample_cnt):
    plt.subplot(321 + (i))
    plt.title(images_fids[i])
    plt.xticks([])
    plt.yticks([])   
    plt.imshow(images_sample[i])

plt.show()

# %% [markdown]
# ## ON TO DEPLOYMENT
