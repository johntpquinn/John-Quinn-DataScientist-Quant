# %% [markdown]
# <h1>E-commerce via Computer Vision</h1>

# %% [markdown]
# ## Machine Learning: Data Extraction (1st Step)

# %% [markdown]
# # Step 1: Set environment variables, re-image serverless, ephmeral instance (if Datalab not already running), imports, unpickle prior data

# %%
# ENVIRONMENT VARIABLES
PROJECT = 'hidden-layers-llc'
REGION  = 'us-east1'
BUCKET  = 'hidden-layers-llc'
MODULE = 'ai'
COMPONENT = 'images-raw'
GS = 'gs://'

# %%
# %%bash
# gcloud config set project hidden-layers-llc
# gcloud config set compute/region us-east1
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %%
# ONLY UNCOMMENT AND RUN THIS SCRIPT IF THIS IS THE 1ST NOTEBOOK OPENED IN THIS SESSION
#!bash install_dl_libs.sh

# %%
# import necessary libraries
import time
import string
import os
import csv
from copy import deepcopy
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
from numpy.random import seed
import pandas as pd
import pickle as pkl
import shutil 
from shutil import copy2
from orderedset import OrderedSet
from collections import OrderedDict
import warnings
from keras.engine import Model
from keras.layers import Input
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Dropout, Activation, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.optimizers import SGD, RMSprop, Adam
from keras.utils import np_utils 
from keras.callbacks import ModelCheckpoint
from keras.applications import VGG16
from keras.models import model_from_json, load_model
from keras.applications.vgg16 import preprocess_input, decode_predictions
import glob
# Now we need TensorFlow itself, as well same control (see Section 3.2 below) of its memory allocation
import tensorflow as tf
from tensorflow import set_random_seed
from keras.backend import clear_session
from keras.backend.tensorflow_backend import set_session
from keras import backend as K
import scipy.misc
import pydot
from random import shuffle
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
warnings.filterwarnings('ignore') # Stop warning about pandas .ix slicing, which is deprecated but most effective
# Out:
# Using TensorFlow backend.

# %%
# GLOBAL VARIABLES - MODELING
# desired data field for each image
desired_fields = ['img_no', 'manufacturer', 'description', 'retailer_sku', 'manufacturer_sku', 'img_url', 'img_name']
curr_dir = os.getcwd() # set the current directory in which this notebook resides
#seed(1)  # set numpy seed for reproducibility
#set_random_seed(2) # set TensorFlow see, also needed for reproducibility

# %%
#retrieve summaries from target site scrape
copy2('../df_pages_CLEAN_pkl.pickle', '.')
copy2('../dir_paths.pickle', '.')
copy2('../brand_dictionary_pkl.pickle', '.')
# Out:
# './brand_dictionary_pkl.pickle'

# %%
# Load the summary DataFrame to map searches on this site to correct labels
with open('df_pages_CLEAN_pkl.pickle', 'rb') as df_pp:
  df_pages = pkl.load(df_pp)

# %%
# Load the path details saved from target site scrape
with open('dir_paths.pickle', 'rb') as df_paths:
  home_dir = pkl.load(df_paths)
  project_folder = pkl.load(df_paths)
  target_site_folder = pkl.load(df_paths)
  images_folder = pkl.load(df_paths)
  images_train_folder = pkl.load(df_paths)
  images_validation_folder = pkl.load(df_paths)
  images_test_folder = pkl.load(df_paths)
  classes_list = pkl.load(df_paths)

# %%
# Load the brand_dict saved from target site scrape
with open('brand_dictionary_pkl.pickle', 'rb') as brand_dict_fid:
   brand_dict = pkl.load(brand_dict_fid)

# %%
# Load the labels_short dictionary, which tells us how many of which labels' images we need to create
with open('data_bal_penult.pickle', 'rb') as labels_short_dict:
  labels_short = pkl.load(labels_short_dict)
  img_counts = pkl.load(labels_short_dict)
  count_min = pkl.load(labels_short_dict)

# %%
# Load the mappings and meta-data persisted in the 1st ML Step (ML_model_1_final.ipynb)
with open('images_detail_pkl.pickle', 'rb') as image_details:
  dir_train_folders = pkl.load(image_details)
  dir_val_folders = pkl.load(image_details)
  df_ground_truth = pkl.load(image_details)
  img_all_idx_dict = pkl.load(image_details)
  img_train_idx_dict = pkl.load(image_details)
  img_val_idx_dict = pkl.load(image_details)
  n_classes = pkl.load(image_details)      #N.B.: This is used extensively below

# %%
# define some required constraints for VGG16 & image dataset paths
labels_list = sorted(classes_list) # Keras generates probabilities by class in alphabetical order
img_height_req, img_width_req, dim_color_channels = 224, 224, 3  # the last (3) is the RGB vector/pixel into VGG16
# paths to images dataset and its subsets
train_dir = './images/train'
validation_dir = './images/validation'
test_dir = './images/test'
top_model_weights_best = 'top_model_weights_Step1.h5'
train_class_cnt = 8 # of the 10 images sourced from other than target site/class 2 were randomly assigned to validation (val)
val_class_cnt = 2 # the 2 of the 10 images sourced from other than target site/class randomly assigned to validation (val)
train_cnt = 232 # 8 test images for each of the 29 classes/retailer_skus
val_cnt = 58 # 2 validation images for each of the 29 classes/retailer_skus
test_cnt = n_classes # 1 test image for each of the 29 classes/retailer_skus

# %% [markdown]
# # Step 2: Sequential Fine-Tuning

# %% [markdown]
# ## Step 2.1: Helper Functions for Balance of this Notebook

# %%
# define a function to convert these BGR images to RGB
def preprocess_input_BGR(x):
    x = x[:,:,::-1]  # convert BGR images to RGB (height=OK,width=OK, but reverse order of 3 color channels, from BGR to RGB)
    return x

# %%
# define a function to process a .jpg (or .jpeg) file received from a user into a tensor for prediction
def process_img_in(img_in_path): # img_in_path is the full path to the .jpg uploaded by the user
  img_height_req, img_width_req = 224, 224
  img = cv2.imread(img_in_path)
  x = deepcopy(img)
  x = cv2.resize(x,(img_height_req, img_width_req)).astype('float32')
  x = cv2.cvtColor(x, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but switch of 1st & 3rd color channels still works
  x = img_to_array(x)
  x = np.true_divide(x, 255) # scale np.array representation of img as required by VGG16
  x = np.expand_dims(x, axis=0) # TensorFlow expects 4th dim, for indices of images (i.e., a rank-4 tensor)

  return x

# %%
# define a function to return the fids of the top-5 matches in the test set to the input img
def get_top_5_matches(pred_labels_top5):
  global test_dir
  pred_fids = []
  pred_imgs = []
  for pred_label in pred_labels_top5:
    pred_fid = pred_label+'.jpg'
    pred_img = cv2.imread(os.path.join(test_dir,pred_label,pred_fid))
    pred_img = cv2.cvtColor(pred_img, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but switch of 1st & 3rd color channels still works
    pred_fids.append(pred_fid)
    pred_imgs.append(pred_img)
  
  return pred_fids, pred_imgs

# %%
# define a helper function to translate the top n prediction indices to class labels (text) for ONE image
def get_top_n_labels_1_img(top_n_idx_img, idx_to_label_dict, n=5):
  if isinstance(top_n_idx_img, np.ndarray):
    top_n_idx_img_list = top_n_idx_img.tolist()
  else:
    top_n_idx_img_list = top_n_idx_img
  pred_labels_top_n = []  # the container/list for the top n predicted labels for 1 image
  pred_labels_top_n = [idx_to_label_dict[i] for i in top_n_idx_img_list]
  
  return pred_labels_top_n

# %%
# define a function to translate the top n prediction indices to class labels (text) for ALL images
def get_top_n_labels_all(top_n_idxs_tout, idx_to_label_dict, n=5):
  pred_labels_top_n_all = [] # the list of list for predicted labels for all predictions
  for top_n_idx_row in top_n_idxs_tout:
    pred_labels_top_n = []  # the container/list for the top n predicted labels for 1 image
    pred_labels_top_n = get_n_pred_labels_1_img(top_n_idx_row, idx_to_label_dict)
    pred_labels_top_n_all.append(pred_labels_top_n)
  
  return pred_labels_top_n_all

# %%
# define a helper function to extract the indices of the top n predictions for ONE image
def get_top_n_idxs_1_img(probs_img, n=5):
  top_n_idxs = [] # the container for the indices for the top n matches for 1 image
  probs_copy = deepcopy(probs_img)
  if isinstance(probs_copy, np.ndarray):
    prob_list = probs_copy.tolist()
  else:
    prob_list = probs_copy
  probs_top_n = deepcopy(prob_list)
  probs_top_n = sorted(probs_top_n, reverse=True)[0:n]
  for prob_top_n in probs_top_n:
    prob_top_n_idx = prob_list.index(prob_top_n)
    top_n_idxs.append(prob_top_n_idx)
  
  return top_n_idxs

# %%
# define a function to extract the indices of the top n predictions for ALL predictions
def get_top_n_idxs_and_labels(prob_array, idx_to_label_dict, n=5):
  probs_all = deepcopy(prob_array)
  top_n_all_idxs = [] # list of lists, each row/sublist of which is the indices of the top n image preds for 1 image
  top_n_all_labels = [] # list of lists, each row/sublist of which is the labels of the top n image preds for 1 image
  for prob_vec_idx, prob_vec in enumerate(probs_all):
    top_n_idxs = [] # the container for those indices for the top n matches for 1 image
    top_n_labels = [] # the container for those labels for the top n matches for 1 image
    prob_vec_copy = deepcopy(probs_all[prob_vec_idx,:])
    top_n_idxs = get_top_n_idxs_1_img(prob_vec_copy, n)
    top_n_labels = get_top_n_labels_1_img(top_n_idxs, idx_to_label_dict, n)
    top_n_all_idxs.append(top_n_idxs)
    top_n_all_labels.append(top_n_labels)
  
  return top_n_all_idxs, top_n_all_labels

# %% [markdown]
# ## Part 2.3 Load a Quality Integrated Model (bn & Classification) & Then Unfreeze More Layers

# %%
# Ensure that current session is set and that seeming problems with TF non-threaded avoided
clear_session()  # https://stackoverflow.com/questions/51032845/single-thread-impacts-model-accuracy-and-loss-with-tensorflow-keras-backend
config = tf.ConfigProto(intra_op_parallelism_threads=8, inter_op_parallelism_threads=24)
# Cause TF to allocate GPU memory dynamically, hopefully obviating out-of_memory ("OOM") & other problems
# From https://github.com/keras-team/keras/issues/4161
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
                                    # (nothing gets printed in Jupyter, only if you run it standalone)
config.allow_soft_placement = True
device_count={'GPU': 8, 'CPU': 16} # Use GPU as default
sess = tf.Session(graph=tf.get_default_graph(), config=config)
set_session(sess)

# %%
with open('vgg16_bn_model.json', 'r') as vgg16_bn_model_json:
  base_model_json = vgg16_bn_model_json.read()
bn_model = model_from_json(base_model_json)
bn_model.load_weights('vgg16_bn_model_json_weights.h5')

my_model = Sequential()
my_model.add(bn_model)
my_model.add(Flatten(input_shape=bn_model.output_shape[1:]))
my_model.add(Dense(256, activation='relu'))
my_model.add(Dropout(0.5))
my_model.add(Dense(n_classes, activation='softmax'))
my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 29)                7453
# =================================================================
# Total params: 21,144,925
# Trainable params: 21,144,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set all but final layer of base/bn-extractor layers as untrainable; allow final to be trained
for layer_idx, layer in enumerate(my_model.get_layer('vgg16').layers):
  if layer_idx < 19:
    print('frozen layer: layer_idx: {} layer.name: {}'.format(layer_idx, layer.name))
    layer.trainable = False
  else:
    print('un-frozen layer: layer_idx: {} layer.name: {}'.format(layer_idx, layer.name))
    layer.trainable = True
# Out:
# frozen layer: layer_idx: 0 layer.name: input_1
# frozen layer: layer_idx: 1 layer.name: block1_conv1
# frozen layer: layer_idx: 2 layer.name: block1_conv2
# frozen layer: layer_idx: 3 layer.name: block1_pool
# frozen layer: layer_idx: 4 layer.name: block2_conv1
# frozen layer: layer_idx: 5 layer.name: block2_conv2
# frozen layer: layer_idx: 6 layer.name: block2_pool
# frozen layer: layer_idx: 7 layer.name: block3_conv1
# frozen layer: layer_idx: 8 layer.name: block3_conv2
# frozen layer: layer_idx: 9 layer.name: block3_conv3
# frozen layer: layer_idx: 10 layer.name: block3_pool
# frozen layer: layer_idx: 11 layer.name: block4_conv1
# frozen layer: layer_idx: 12 layer.name: block4_conv2
# frozen layer: layer_idx: 13 layer.name: block4_conv3
# frozen layer: layer_idx: 14 layer.name: block4_pool
# frozen layer: layer_idx: 15 layer.name: block5_conv1
# frozen layer: layer_idx: 16 layer.name: block5_conv2
# frozen layer: layer_idx: 17 layer.name: block5_conv3
# frozen layer: layer_idx: 18 layer.name: block5_pool

# %% [markdown]
# ## Step 2.3 Data Generators

# %%
# create a TRAIN set ImageDataGenerator
batch_size = 4
train_datagen = ImageDataGenerator(rescale=1. / 255, preprocessing_function = preprocess_input_BGR)
                                   
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height_req, img_width_req),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)
# Out:
# Found 232 images belonging to 29 classes.

# %%
# create a VAL (VALIDATION) set ImageDataGenerator 
validation_datagen = ImageDataGenerator(rescale=1. / 255, preprocessing_function = preprocess_input_BGR)

validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                              target_size=(img_height_req, img_width_req),
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              shuffle=False)
# Out:
# Found 58 images belonging to 29 classes.

# %% [markdown]
# ## Step 2.3 Integrated Model - Initial Training

# %%
# set model_top's hyperparamaters
learning_rate = 1.5e-3
epochs = 100 # increasing epsilon (below) slows training, suggesting that more epochs should be needed
epsilon = 1e-3 # increasing this deterrant to division by zero adds stability to the system/model
decay_rate = learning_rate / epochs

# %%
# ready the top _model for training
rmsprop = RMSprop(lr=learning_rate, epsilon=epsilon, decay=decay_rate)
my_model.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath=top_model_weights_best, verbose=1, save_best_only=True)
#execute training
history = my_model.fit_generator(train_generator,
                                 samples_per_epoch=train_cnt,
                                 epochs=epochs,
                                 validation_data=validation_generator,
                                 nb_val_samples=val_cnt,
                                 callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 11s 194ms/step - loss: 14.3420 - acc: 0.0603 - val_loss: 14.3430 - val_acc: 0.0398
#
# Epoch 00001: val_loss improved from inf to 14.34297, saving model to top_model_weights_Step1.h5
# Epoch 2/100
# 58/58 [==============================] - 9s 152ms/step - loss: 14.3331 - acc: 0.0819 - val_loss: 14.1787 - val_acc: 0.0357
#
# Epoch 00002: val_loss improved from 14.34297 to 14.17871, saving model to top_model_weights_Step1.h5
# Epoch 3/100
# 58/58 [==============================] - 9s 153ms/step - loss: 14.6512 - acc: 0.0690 - val_loss: 13.9807 - val_acc: 0.1071
#
# Epoch 00003: val_loss improved from 14.17871 to 13.98072, saving model to top_model_weights_Step1.h5
# Epoch 4/100
# 58/58 [==============================] - 9s 152ms/step - loss: 14.3613 - acc: 0.0819 - val_loss: 13.4466 - val_acc: 0.0804
#
# Epoch 00004: val_loss improved from 13.98072 to 13.44664, saving model to top_model_weights_Step1.h5
# Epoch 5/100
# 58/58 [==============================] - 9s 153ms/step - loss: 13.8762 - acc: 0.1121 - val_loss: 12.7785 - val_acc: 0.1786
#
# Epoch 00005: val_loss improved from 13.44664 to 12.77852, saving model to top_model_weights_Step1.h5
# Epoch 6/100
# 58/58 [==============================] - 9s 152ms/step - loss: 13.6342 - acc: 0.1164 - val_loss: 13.5308 - val_acc: 0.1607
#
# Epoch 00006: val_loss did not improve from 12.77852
# Epoch 7/100
# 58/58 [==============================] - 9s 153ms/step - loss: 13.7474 - acc: 0.1121 - val_loss: 13.2644 - val_acc: 0.1518
#
# Epoch 00007: val_loss did not improve from 12.77852
# Epoch 8/100
# 58/58 [==============================] - 9s 153ms/step - loss: 13.5443 - acc: 0.1164 - val_loss: 11.8396 - val_acc: 0.1770
#
# Epoch 00008: val_loss improved from 12.77852 to 11.83955, saving model to top_model_weights_Step1.h5
# Epoch 9/100
# 58/58 [==============================] - 9s 153ms/step - loss: 13.1096 - acc: 0.1207 - val_loss: 12.0733 - val_acc: 0.1964
#
# Epoch 00009: val_loss did not improve from 11.83955
# Epoch 10/100
# 58/58 [==============================] - 9s 153ms/step - loss: 12.6274 - acc: 0.1552 - val_loss: 12.3468 - val_acc: 0.1964
#
# Epoch 00010: val_loss did not improve from 11.83955
# Epoch 11/100
# 58/58 [==============================] - 9s 153ms/step - loss: 12.3401 - acc: 0.1810 - val_loss: 12.0047 - val_acc: 0.2321
#
# Epoch 00011: val_loss did not improve from 11.83955
# Epoch 12/100
# 58/58 [==============================] - 9s 153ms/step - loss: 11.0604 - acc: 0.2198 - val_loss: 10.6714 - val_acc: 0.2723
#
# Epoch 00012: val_loss improved from 11.83955 to 10.67136, saving model to top_model_weights_Step1.h5
# Epoch 13/100
# 58/58 [==============================] - 9s 152ms/step - loss: 10.5597 - acc: 0.2414 - val_loss: 10.0788 - val_acc: 0.2321
#
# Epoch 00013: val_loss improved from 10.67136 to 10.07879, saving model to top_model_weights_Step1.h5
# Epoch 14/100
# 58/58 [==============================] - 9s 153ms/step - loss: 5.9344 - acc: 0.2716 - val_loss: 2.7159 - val_acc: 0.3080
#
# Epoch 00014: val_loss improved from 10.07879 to 2.71594, saving model to top_model_weights_Step1.h5
# Epoch 15/100
# 58/58 [==============================] - 9s 152ms/step - loss: 2.9039 - acc: 0.2672 - val_loss: 2.8291 - val_acc: 0.2679
#
# Epoch 00015: val_loss did not improve from 2.71594
# Epoch 16/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.6126 - acc: 0.2974 - val_loss: 2.6210 - val_acc: 0.2876
#
# Epoch 00016: val_loss improved from 2.71594 to 2.62103, saving model to top_model_weights_Step1.h5
# Epoch 17/100
# 58/58 [==============================] - 9s 152ms/step - loss: 2.4044 - acc: 0.3534 - val_loss: 2.3457 - val_acc: 0.3214
#
# Epoch 00017: val_loss improved from 2.62103 to 2.34571, saving model to top_model_weights_Step1.h5
# Epoch 18/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.5674 - acc: 0.3319 - val_loss: 2.3453 - val_acc: 0.3036
#
# Epoch 00018: val_loss improved from 2.34571 to 2.34530, saving model to top_model_weights_Step1.h5
# Epoch 19/100
# 58/58 [==============================] - 9s 152ms/step - loss: 2.4418 - acc: 0.3750 - val_loss: 2.3170 - val_acc: 0.3304
#
# Epoch 00019: val_loss improved from 2.34530 to 2.31698, saving model to top_model_weights_Step1.h5
# Epoch 20/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.2664 - acc: 0.4052 - val_loss: 2.5367 - val_acc: 0.3527
#
# Epoch 00020: val_loss did not improve from 2.31698
# Epoch 21/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.2187 - acc: 0.4267 - val_loss: 2.1436 - val_acc: 0.3036
#
# Epoch 00021: val_loss improved from 2.31698 to 2.14355, saving model to top_model_weights_Step1.h5
# Epoch 22/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.1432 - acc: 0.4009 - val_loss: 2.2990 - val_acc: 0.3259
#
# Epoch 00022: val_loss did not improve from 2.14355
# Epoch 23/100
# 58/58 [==============================] - 9s 153ms/step - loss: 2.0194 - acc: 0.4181 - val_loss: 2.1553 - val_acc: 0.3407
#
# Epoch 00023: val_loss did not improve from 2.14355
# Epoch 24/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.9533 - acc: 0.4009 - val_loss: 2.0648 - val_acc: 0.3839
#
# Epoch 00024: val_loss improved from 2.14355 to 2.06476, saving model to top_model_weights_Step1.h5
# Epoch 25/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.9999 - acc: 0.4224 - val_loss: 2.6048 - val_acc: 0.4375
#
# Epoch 00025: val_loss did not improve from 2.06476
# Epoch 26/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.8675 - acc: 0.4397 - val_loss: 2.2903 - val_acc: 0.3527
#
# Epoch 00026: val_loss did not improve from 2.06476
# Epoch 27/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.8892 - acc: 0.4397 - val_loss: 2.7998 - val_acc: 0.3438
#
# Epoch 00027: val_loss did not improve from 2.06476
# Epoch 28/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.8542 - acc: 0.4957 - val_loss: 2.1078 - val_acc: 0.4286
#
# Epoch 00028: val_loss did not improve from 2.06476
# Epoch 29/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.6695 - acc: 0.5043 - val_loss: 2.9784 - val_acc: 0.3036
#
# Epoch 00029: val_loss did not improve from 2.06476
# Epoch 30/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.5848 - acc: 0.5474 - val_loss: 2.4740 - val_acc: 0.4286
#
# Epoch 00030: val_loss did not improve from 2.06476
# Epoch 31/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.6186 - acc: 0.5000 - val_loss: 1.9620 - val_acc: 0.3584
#
# Epoch 00031: val_loss improved from 2.06476 to 1.96202, saving model to top_model_weights_Step1.h5
# Epoch 32/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.4983 - acc: 0.5603 - val_loss: 2.2775 - val_acc: 0.4062
#
# Epoch 00032: val_loss did not improve from 1.96202
# Epoch 33/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.6169 - acc: 0.5259 - val_loss: 2.1069 - val_acc: 0.4554
#
# Epoch 00033: val_loss did not improve from 1.96202
# Epoch 34/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.7343 - acc: 0.5216 - val_loss: 2.2758 - val_acc: 0.4196
#
# Epoch 00034: val_loss did not improve from 1.96202
# Epoch 35/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5253 - acc: 0.5388 - val_loss: 2.2583 - val_acc: 0.3929
#
# Epoch 00035: val_loss did not improve from 1.96202
# Epoch 36/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5457 - acc: 0.5690 - val_loss: 2.1235 - val_acc: 0.4107
#
# Epoch 00036: val_loss did not improve from 1.96202
# Epoch 37/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5944 - acc: 0.5086 - val_loss: 1.9657 - val_acc: 0.4643
#
# Epoch 00037: val_loss did not improve from 1.96202
# Epoch 38/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.4342 - acc: 0.5647 - val_loss: 2.4869 - val_acc: 0.4646
#
# Epoch 00038: val_loss did not improve from 1.96202
# Epoch 39/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5303 - acc: 0.5431 - val_loss: 2.4645 - val_acc: 0.4375
#
# Epoch 00039: val_loss did not improve from 1.96202
# Epoch 40/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.4479 - acc: 0.6164 - val_loss: 2.8029 - val_acc: 0.4018
#
# Epoch 00040: val_loss did not improve from 1.96202
# Epoch 41/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5955 - acc: 0.5388 - val_loss: 2.1810 - val_acc: 0.3839
#
# Epoch 00041: val_loss did not improve from 1.96202
# Epoch 42/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.4030 - acc: 0.5905 - val_loss: 2.5012 - val_acc: 0.4509
#
# Epoch 00042: val_loss did not improve from 1.96202
# Epoch 43/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.4281 - acc: 0.5690 - val_loss: 2.2556 - val_acc: 0.4241
#
# Epoch 00043: val_loss did not improve from 1.96202
# Epoch 44/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.4336 - acc: 0.5431 - val_loss: 2.2362 - val_acc: 0.4286
#
# Epoch 00044: val_loss did not improve from 1.96202
# Epoch 45/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.3382 - acc: 0.5819 - val_loss: 1.9213 - val_acc: 0.4911
#
# Epoch 00045: val_loss improved from 1.96202 to 1.92132, saving model to top_model_weights_Step1.h5
# Epoch 46/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.2991 - acc: 0.6207 - val_loss: 2.4895 - val_acc: 0.4602
#
# Epoch 00046: val_loss did not improve from 1.92132
# Epoch 47/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.5179 - acc: 0.5517 - val_loss: 2.2128 - val_acc: 0.4955
#
# Epoch 00047: val_loss did not improve from 1.92132
# Epoch 48/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2394 - acc: 0.6638 - val_loss: 2.3573 - val_acc: 0.4821
#
# Epoch 00048: val_loss did not improve from 1.92132
# Epoch 49/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2166 - acc: 0.6466 - val_loss: 2.3200 - val_acc: 0.4955
#
# Epoch 00049: val_loss did not improve from 1.92132
# Epoch 50/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1758 - acc: 0.6422 - val_loss: 2.2995 - val_acc: 0.4911
#
# Epoch 00050: val_loss did not improve from 1.92132
# Epoch 51/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.4755 - acc: 0.5948 - val_loss: 2.9805 - val_acc: 0.4241
#
# Epoch 00051: val_loss did not improve from 1.92132
# Epoch 52/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2501 - acc: 0.6293 - val_loss: 2.2595 - val_acc: 0.4732
#
# Epoch 00052: val_loss did not improve from 1.92132
# Epoch 53/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.3143 - acc: 0.5991 - val_loss: 2.6180 - val_acc: 0.4115
#
# Epoch 00053: val_loss did not improve from 1.92132
# Epoch 54/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2315 - acc: 0.6466 - val_loss: 2.5452 - val_acc: 0.4732
#
# Epoch 00054: val_loss did not improve from 1.92132
# Epoch 55/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2737 - acc: 0.6293 - val_loss: 2.3220 - val_acc: 0.4554
#
# Epoch 00055: val_loss did not improve from 1.92132
# Epoch 56/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2480 - acc: 0.5905 - val_loss: 3.0477 - val_acc: 0.4241
#
# Epoch 00056: val_loss did not improve from 1.92132
# Epoch 57/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2895 - acc: 0.6466 - val_loss: 2.7356 - val_acc: 0.4688
#
# Epoch 00057: val_loss did not improve from 1.92132
# Epoch 58/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2398 - acc: 0.6164 - val_loss: 2.0588 - val_acc: 0.4554
#
# Epoch 00058: val_loss did not improve from 1.92132
# Epoch 59/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.3382 - acc: 0.6293 - val_loss: 2.3867 - val_acc: 0.4643
#
# Epoch 00059: val_loss did not improve from 1.92132
# Epoch 60/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.2032 - acc: 0.6034 - val_loss: 2.3867 - val_acc: 0.5223
#
# Epoch 00060: val_loss did not improve from 1.92132
# Epoch 61/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.3308 - acc: 0.6164 - val_loss: 2.2535 - val_acc: 0.5000
#
# Epoch 00061: val_loss did not improve from 1.92132
# Epoch 62/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1824 - acc: 0.5948 - val_loss: 2.5198 - val_acc: 0.4955
#
# Epoch 00062: val_loss did not improve from 1.92132
# Epoch 63/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1788 - acc: 0.6293 - val_loss: 2.7413 - val_acc: 0.4821
#
# Epoch 00063: val_loss did not improve from 1.92132
# Epoch 64/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1609 - acc: 0.6466 - val_loss: 2.6514 - val_acc: 0.4375
#
# Epoch 00064: val_loss did not improve from 1.92132
# Epoch 65/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0193 - acc: 0.6983 - val_loss: 2.4479 - val_acc: 0.4911
#
# Epoch 00065: val_loss did not improve from 1.92132
# Epoch 66/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1541 - acc: 0.6336 - val_loss: 2.3358 - val_acc: 0.4955
#
# Epoch 00066: val_loss did not improve from 1.92132
# Epoch 67/100
# 58/58 [==============================] - 9s 154ms/step - loss: 0.9235 - acc: 0.6940 - val_loss: 2.4301 - val_acc: 0.4955
#
# Epoch 00067: val_loss did not improve from 1.92132
# Epoch 68/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0743 - acc: 0.6638 - val_loss: 2.4815 - val_acc: 0.4823
#
# Epoch 00068: val_loss did not improve from 1.92132
# Epoch 69/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0876 - acc: 0.6767 - val_loss: 2.9501 - val_acc: 0.4554
#
# Epoch 00069: val_loss did not improve from 1.92132
# Epoch 70/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1718 - acc: 0.6379 - val_loss: 2.3563 - val_acc: 0.4866
#
# Epoch 00070: val_loss did not improve from 1.92132
# Epoch 71/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9850 - acc: 0.6940 - val_loss: 2.8496 - val_acc: 0.4107
#
# Epoch 00071: val_loss did not improve from 1.92132
# Epoch 72/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0660 - acc: 0.7026 - val_loss: 2.8406 - val_acc: 0.5045
#
# Epoch 00072: val_loss did not improve from 1.92132
# Epoch 73/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.2449 - acc: 0.6897 - val_loss: 2.6858 - val_acc: 0.5223
#
# Epoch 00073: val_loss did not improve from 1.92132
# Epoch 74/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0863 - acc: 0.6638 - val_loss: 2.9216 - val_acc: 0.4464
#
# Epoch 00074: val_loss did not improve from 1.92132
# Epoch 75/100
# 58/58 [==============================] - 9s 152ms/step - loss: 1.0635 - acc: 0.6767 - val_loss: 2.2244 - val_acc: 0.5580
#
# Epoch 00075: val_loss did not improve from 1.92132
# Epoch 76/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0629 - acc: 0.6767 - val_loss: 2.9533 - val_acc: 0.4469
#
# Epoch 00076: val_loss did not improve from 1.92132
# Epoch 77/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0641 - acc: 0.6552 - val_loss: 2.4278 - val_acc: 0.4420
#
# Epoch 00077: val_loss did not improve from 1.92132
# Epoch 78/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1208 - acc: 0.6466 - val_loss: 2.5384 - val_acc: 0.5089
#
# Epoch 00078: val_loss did not improve from 1.92132
# Epoch 79/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0194 - acc: 0.7026 - val_loss: 3.3077 - val_acc: 0.4598
#
# Epoch 00079: val_loss did not improve from 1.92132
# Epoch 80/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1234 - acc: 0.6638 - val_loss: 3.1625 - val_acc: 0.4375
#
# Epoch 00080: val_loss did not improve from 1.92132
# Epoch 81/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0882 - acc: 0.6810 - val_loss: 2.8011 - val_acc: 0.5134
#
# Epoch 00081: val_loss did not improve from 1.92132
# Epoch 82/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1099 - acc: 0.6681 - val_loss: 2.9708 - val_acc: 0.4821
#
# Epoch 00082: val_loss did not improve from 1.92132
# Epoch 83/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1335 - acc: 0.6552 - val_loss: 2.5376 - val_acc: 0.4823
#
# Epoch 00083: val_loss did not improve from 1.92132
# Epoch 84/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1629 - acc: 0.6638 - val_loss: 2.6899 - val_acc: 0.4196
#
# Epoch 00084: val_loss did not improve from 1.92132
# Epoch 85/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9931 - acc: 0.6853 - val_loss: 2.5199 - val_acc: 0.5402
#
# Epoch 00085: val_loss did not improve from 1.92132
# Epoch 86/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1289 - acc: 0.6767 - val_loss: 2.5090 - val_acc: 0.4554
#
# Epoch 00086: val_loss did not improve from 1.92132
# Epoch 87/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9386 - acc: 0.6897 - val_loss: 2.7863 - val_acc: 0.4866
#
# Epoch 00087: val_loss did not improve from 1.92132
# Epoch 88/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9510 - acc: 0.7328 - val_loss: 3.2134 - val_acc: 0.4241
#
# Epoch 00088: val_loss did not improve from 1.92132
# Epoch 89/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.1616 - acc: 0.6897 - val_loss: 2.7669 - val_acc: 0.4643
#
# Epoch 00089: val_loss did not improve from 1.92132
# Epoch 90/100
# 58/58 [==============================] - 9s 152ms/step - loss: 0.9959 - acc: 0.6724 - val_loss: 2.6428 - val_acc: 0.4777
#
# Epoch 00090: val_loss did not improve from 1.92132
# Epoch 91/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9590 - acc: 0.6983 - val_loss: 2.7395 - val_acc: 0.4823
#
# Epoch 00091: val_loss did not improve from 1.92132
# Epoch 92/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0131 - acc: 0.6724 - val_loss: 2.7461 - val_acc: 0.4241
#
# Epoch 00092: val_loss did not improve from 1.92132
# Epoch 93/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9863 - acc: 0.7112 - val_loss: 2.9985 - val_acc: 0.5179
#
# Epoch 00093: val_loss did not improve from 1.92132
# Epoch 94/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0850 - acc: 0.7069 - val_loss: 2.5690 - val_acc: 0.4955
#
# Epoch 00094: val_loss did not improve from 1.92132
# Epoch 95/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9622 - acc: 0.7155 - val_loss: 2.6862 - val_acc: 0.4866
#
# Epoch 00095: val_loss did not improve from 1.92132
# Epoch 96/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9725 - acc: 0.6940 - val_loss: 2.7190 - val_acc: 0.4955
#
# Epoch 00096: val_loss did not improve from 1.92132
# Epoch 97/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9096 - acc: 0.7328 - val_loss: 2.5382 - val_acc: 0.5089
#
# Epoch 00097: val_loss did not improve from 1.92132
# Epoch 98/100
# 58/58 [==============================] - 9s 153ms/step - loss: 0.9099 - acc: 0.7026 - val_loss: 2.7554 - val_acc: 0.4646
#
# Epoch 00098: val_loss did not improve from 1.92132
# Epoch 99/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0350 - acc: 0.6940 - val_loss: 2.5706 - val_acc: 0.5134
#
# Epoch 00099: val_loss did not improve from 1.92132
# Epoch 100/100
# 58/58 [==============================] - 9s 153ms/step - loss: 1.0060 - acc: 0.6810 - val_loss: 2.5712 - val_acc: 0.4732
#
# Epoch 00100: val_loss did not improve from 1.92132

# %%
(eval_loss, eval_accuracy) = my_model.evaluate_generator(train_generator,train_cnt)

# %%
# Print most common usual results
train_accuracy = history.history['acc'][-1]
train_loss = history.history['loss'][-1]
print('The ultimate TRAINING Accuracy was {:.4f}%'.format(train_accuracy * 100))
print('The ultimate EVALUATION Accuracy was {:.4f}%'.format(eval_accuracy * 100))
print('The ultimate TRAINING Loss was {}'.format(train_loss))
print('The ultimate EVALUATION Loss was {}'.format(eval_loss))

# Graph the results
plt.clf()
graph_cnt = 2

# Total Graph size and Top Title
plt.figure(figsize=(16,8))
plt.suptitle('Summary of Accuracy and Model Loss Over Epoch', fontsize=30, weight='bold')
# Build Graph Contents
training_metrics = [history.history['acc'], history.history['loss']]
validation_metrics = [history.history['val_acc'], history.history['val_loss']]
horizontal_titles = ['model accuracy', 'model loss']
vertical_axis_labels = ['accuracy', 'loss']
# Build the graph contents
for i in range(graph_cnt):
    plt.subplot(121 + (i))
    plt.plot(training_metrics[i], color='green')
    plt.plot(validation_metrics[i], color='red')
    plt.title(horizontal_titles[i])
    plt.ylabel(vertical_axis_labels[i])
    plt.xlabel('epoch')
    plt.legend(['training', 'testing'], loc='best', prop={'size': 25})

plt.show()
plt.savefig('my_model_Step1.png')
# Out:
# The ultimate TRAINING Accuracy was 68.1034%
# The ultimate EVALUATION Accuracy was 91.3793%
# The ultimate TRAINING Loss was 1.0059709184460786
# The ultimate EVALUATION Loss was 0.22757982520768227

# %%
# persist integrated model (architecture)
model_integrated_json = my_model.to_json()
with open("my_model_Step1.json", "w") as json_file:
    json_file.write(model_integrated_json)

# %%
# persist model_top (graph of weights)
my_model.save_weights("my_model_weights_Step1.h5")

# %%
# reload the same model_top architecture from this architecture
with open('my_model_Step1.json', 'r') as model_json:
  json_file = model_json.read()
my_model = model_from_json(json_file)

# %%
# load weights from best trial with some stochasticitty/volatility over a handful of trials (v4 better results)
my_model.load_weights(top_model_weights_best)    # THIS SHOULD BE CHANGED BACK TO "model_flatten_weights.h5"

# %%
model_name = "tf_serving_keras_wrenches_Step1.h5"
my_model.save(os.path.join('models',model_name))

# %%
# compile that model with the same parameters used to build it (above)
my_model.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Part 2.3.1 Let's show how the model performed, looking at the accuracy of predictions of the training set as validated by the validation set

# %%
# # First obtain the predictions & related data from the weighted graph generated with the VGG16 topped model
prediction_probs_val = my_model.predict_generator(validation_generator)
fids_ground_truth_val = validation_generator.filenames
label_to_idx_val_dict =  validation_generator.class_indices
idx_to_label_val_dict = dict((label, idx) for idx, label in label_to_idx_val_dict.items())

# %%
# Calculate the top-1 accuracy rate inputs
top_1_idxs_val_todos, top_1_labels_val_todos = get_top_n_idxs_and_labels(prediction_probs_val, idx_to_label_val_dict, 1)

# %%
# calculate the 1% accuracy rate in light of non-read files (both validation and train)
i = 0
error_count_1_val = 0

#fid_ground_truth_prior = fids_ground_truth_val[0].split('/')[0]
for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_val):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label != top_1_labels_val_todos[i][0]:
      print('ERROR: fid_truth_label: {} & top_1_labels_val_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_val_todos[i][0]))
      error_count_1_val += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_1_labels_val_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_val_todos[i][0]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-1 val errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_1_val, i, (1 - (error_count_1_val)/i)*100))
# Out:
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078608 & top_1_labels_val_todos[i][0]: IRW_BM2078606
# CORRECT: fid_truth_label: IRW_BM2078608 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078612 & top_1_labels_val_todos[i][0]: IRW_BM2078608
# CORRECT: fid_truth_label: IRW_BM2078612 & top_1_labels_val_todos[i][0]: IRW_BM2078612
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_val_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_val_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_val_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_val_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_val_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_val_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_val_todos[i][0]: PTY_FA-113-8TAVSE
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_val_todos[i][0]: PTY_FA-113-8TAVSE
# ERROR: fid_truth_label: PTY_J708L & top_1_labels_val_todos[i][0]: PTY_J712S
# CORRECT: fid_truth_label: PTY_J708L & top_1_labels_val_todos[i][0]: PTY_J708L
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_val_todos[i][0]: SNY_85-610
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_val_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: PTY_J712S & top_1_labels_val_todos[i][0]: SNY_87-369
# ERROR: fid_truth_label: PTY_J712S & top_1_labels_val_todos[i][0]: PTY_J708L
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_val_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: RTC_86907 & top_1_labels_val_todos[i][0]: RTC_86922
# CORRECT: fid_truth_label: RTC_86907 & top_1_labels_val_todos[i][0]: RTC_86907
# ERROR: fid_truth_label: RTC_86917 & top_1_labels_val_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: RTC_86917 & top_1_labels_val_todos[i][0]: RTC_86917
# CORRECT: fid_truth_label: RTC_86922 & top_1_labels_val_todos[i][0]: RTC_86922
# ERROR: fid_truth_label: RTC_86922 & top_1_labels_val_todos[i][0]: RTC_86927
# ERROR: fid_truth_label: RTC_86927 & top_1_labels_val_todos[i][0]: RTC_86922
# CORRECT: fid_truth_label: RTC_86927 & top_1_labels_val_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_val_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_val_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_val_todos[i][0]: SBD_J795S
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_val_todos[i][0]: SBD_J795S
# ERROR: fid_truth_label: SNY_85-610 & top_1_labels_val_todos[i][0]: SNY_87-473
# CORRECT: fid_truth_label: SNY_85-610 & top_1_labels_val_todos[i][0]: SNY_85-610
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_val_todos[i][0]: SNY_85-762
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_val_todos[i][0]: SNY_85-762
# ERROR: fid_truth_label: SNY_87-367 & top_1_labels_val_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: SNY_87-367 & top_1_labels_val_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: SNY_87-369 & top_1_labels_val_todos[i][0]: SNY_87-473
# CORRECT: fid_truth_label: SNY_87-369 & top_1_labels_val_todos[i][0]: SNY_87-369
# CORRECT: fid_truth_label: SNY_87-471 & top_1_labels_val_todos[i][0]: SNY_87-471
# ERROR: fid_truth_label: SNY_87-471 & top_1_labels_val_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: SNY_87-473 & top_1_labels_val_todos[i][0]: SNY_87-367
# ERROR: fid_truth_label: SNY_87-473 & top_1_labels_val_todos[i][0]: SNY_87-471
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_val_todos[i][0]: SNY_90-949
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_val_todos[i][0]: SNY_90-949
# CORRECT: fid_truth_label: SNY_90-949 & top_1_labels_val_todos[i][0]: SNY_90-949
# ERROR: fid_truth_label: SNY_90-949 & top_1_labels_val_todos[i][0]: SNY_90-950
# ERROR: fid_truth_label: SNY_90-950 & top_1_labels_val_todos[i][0]: SNY_90-949
# ERROR: fid_truth_label: SNY_90-950 & top_1_labels_val_todos[i][0]: SNY_90-948
# ERROR: fid_truth_label: URR_708S & top_1_labels_val_todos[i][0]: SNY_87-471
# CORRECT: fid_truth_label: URR_708S & top_1_labels_val_todos[i][0]: URR_708S
# CORRECT: fid_truth_label: URR_795G & top_1_labels_val_todos[i][0]: URR_795G
# CORRECT: fid_truth_label: URR_795G & top_1_labels_val_todos[i][0]: URR_795G
#
# ____________________________ FINAL RESULTS_____________________
# top-1 val errors: 30 wrong out of 58 predictions, or 48.2759% accuracy

# %%
# calculate the top-5 accuracy rate inputs
top_5_idxs_val_todos, top_5_labels_val_todos = get_top_n_idxs_and_labels(prediction_probs_val, idx_to_label_val_dict, 5)

# %%
# calculate the 5% accuracy rate in light of non-read files (both validation and test)
i = 0
error_count_5_val = 0

#fid_ground_truth_prior = fids_ground_truth_val[0].split('/')[0]
for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_val):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label not in top_5_labels_val_todos[i]:
      print('ERROR: fid_truth_label: {} & top_5_labels_val_todos[i]: {}'.format(fid_truth_label, top_5_labels_val_todos[i]))
      error_count_5_val += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_5_labels_val_todos[i]: {}'.format(fid_truth_label, top_5_labels_val_todos[i]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-5 val errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_5_val, i, (1 - (error_count_5_val)/i)*100))
# Out:
# ERROR: fid_truth_label: IRW_BM2078606 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'SNY_90-949', 'IRW_BM2078610', 'SNY_90-950']
# CORRECT: fid_truth_label: IRW_BM2078606 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078700', 'IRW_BM2078606']
# ERROR: fid_truth_label: IRW_BM2078608 & top_5_labels_val_todos[i]: ['IRW_BM2078606', 'SNY_90-948', 'SNY_87-369', 'SNY_85-762', 'IRW_BM2078706']
# CORRECT: fid_truth_label: IRW_BM2078608 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'SNY_90-949', 'SNY_90-948']
# CORRECT: fid_truth_label: IRW_BM2078610 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'SNY_90-949', 'SNY_90-950']
# CORRECT: fid_truth_label: IRW_BM2078610 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'SNY_90-949', 'SNY_90-948']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_val_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'SNY_90-948', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_val_todos[i]: ['IRW_BM2078612', 'IRW_BM2078608', 'SNY_87-369', 'SNY_85-762', 'SNY_87-367']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_val_todos[i]: ['IRW_BM2078700', 'SBD_J795S', 'PTY_FA-113-8TAVSE', 'SBD_J795G', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_val_todos[i]: ['IRW_BM2078700', 'SBD_J795S', 'PTY_FA-113-8TAVSE', 'SBD_J795G', 'SNY_90-949']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_val_todos[i]: ['IRW_BM2078706', 'SNY_85-762', 'SNY_87-369', 'RTC_86907', 'SNY_87-471']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_val_todos[i]: ['IRW_BM2078706', 'SNY_87-369', 'SNY_85-762', 'RTC_86907', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_val_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86922', 'RTC_86907', 'SNY_85-762']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_val_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86907', 'RTC_86922', 'SNY_85-762']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_val_todos[i]: ['PTY_FA-113-8TAVSE', 'URR_795G', 'SNY_87-471', 'IRW_BM2078610', 'SNY_87-369']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_val_todos[i]: ['PTY_FA-113-8TAVSE', 'SBD_J795G', 'KTI_3239', 'IRW_BM2078706', 'SNY_90-948']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708L', 'PTY_J715S', 'PTY_J708S', 'RTC_86917']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_val_todos[i]: ['PTY_J708L', 'RTC_86917', 'SNY_87-473', 'RTC_86927', 'PTY_J712S']
# ERROR: fid_truth_label: PTY_J708S & top_5_labels_val_todos[i]: ['SNY_85-610', 'RTC_86922', 'RTC_86907', 'RTC_86917', 'RTC_86927']
# ERROR: fid_truth_label: PTY_J708S & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-367', 'PTY_J708L', 'RTC_86917', 'RTC_86922']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_val_todos[i]: ['SNY_87-369', 'SNY_87-473', 'SNY_87-471', 'PTY_J712S', 'PTY_J715S']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_val_todos[i]: ['PTY_J708L', 'PTY_J712S', 'PTY_J715S', 'URR_708S', 'PTY_J708S']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J715S', 'URR_708S', 'SNY_87-369', 'SNY_85-762']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_val_todos[i]: ['PTY_J712S', 'PTY_J708L', 'PTY_J715S', 'PTY_J708S', 'RTC_86917']
# CORRECT: fid_truth_label: RTC_86907 & top_5_labels_val_todos[i]: ['RTC_86922', 'RTC_86917', 'RTC_86907', 'RTC_86927', 'SNY_87-473']
# CORRECT: fid_truth_label: RTC_86907 & top_5_labels_val_todos[i]: ['RTC_86907', 'RTC_86922', 'RTC_86927', 'RTC_86917', 'SNY_87-473']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86907', 'RTC_86917', 'RTC_86922', 'SNY_87-473']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_val_todos[i]: ['RTC_86917', 'RTC_86927', 'RTC_86922', 'RTC_86907', 'PTY_J708L']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_val_todos[i]: ['RTC_86922', 'RTC_86927', 'KTI_3239', 'SNY_87-471', 'RTC_86907']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86922', 'RTC_86907', 'KTI_3239', 'RTC_86917']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_val_todos[i]: ['RTC_86922', 'RTC_86927', 'RTC_86907', 'RTC_86917', 'KTI_3239']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_val_todos[i]: ['RTC_86927', 'RTC_86907', 'RTC_86917', 'RTC_86922', 'SNY_87-473']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_val_todos[i]: ['SBD_J795G', 'SBD_J795S', 'URR_795G', 'PTY_FA-113-8TAVSE', 'SNY_85-762']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_val_todos[i]: ['SBD_J795G', 'SBD_J795S', 'URR_795G', 'SNY_85-762', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_val_todos[i]: ['SBD_J795S', 'SBD_J795G', 'PTY_J708L', 'SNY_90-950', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_val_todos[i]: ['SBD_J795S', 'SBD_J795G', 'PTY_J708L', 'SNY_90-950', 'PTY_FA-113-8TAVSE']
# ERROR: fid_truth_label: SNY_85-610 & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-369', 'IRW_BM2078706', 'IRW_BM2078608', 'URR_708S']
# CORRECT: fid_truth_label: SNY_85-610 & top_5_labels_val_todos[i]: ['SNY_85-610', 'RTC_86922', 'RTC_86917', 'RTC_86907', 'RTC_86927']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_val_todos[i]: ['SNY_85-762', 'SNY_87-369', 'RTC_86927', 'SNY_87-367', 'IRW_BM2078606']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_val_todos[i]: ['SNY_85-762', 'IRW_BM2078606', 'SNY_87-369', 'RTC_86927', 'SNY_87-367']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-367', 'RTC_86917', 'RTC_86922', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-367', 'RTC_86917', 'RTC_86922', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-369', 'SNY_87-471', 'IRW_BM2078610', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_val_todos[i]: ['SNY_87-369', 'SNY_87-367', 'SNY_85-762', 'SNY_87-473', 'PTY_J712S']
# CORRECT: fid_truth_label: SNY_87-471 & top_5_labels_val_todos[i]: ['SNY_87-471', 'IRW_BM2078610', 'SNY_87-369', 'SNY_87-473', 'SBD_J795S']
# ERROR: fid_truth_label: SNY_87-471 & top_5_labels_val_todos[i]: ['SNY_87-473', 'SNY_87-369', 'SNY_85-762', 'IRW_BM2078612', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_87-473 & top_5_labels_val_todos[i]: ['SNY_87-367', 'SNY_87-473', 'PTY_J708L', 'RTC_86922', 'RTC_86917']
# ERROR: fid_truth_label: SNY_87-473 & top_5_labels_val_todos[i]: ['SNY_87-471', 'SNY_87-369', 'SNY_87-367', 'PTY_J708L', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_val_todos[i]: ['SNY_90-949', 'SNY_90-948', 'SNY_90-950', 'URR_708S', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_val_todos[i]: ['SNY_90-949', 'SNY_90-950', 'SNY_90-948', 'URR_708S', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_90-949 & top_5_labels_val_todos[i]: ['SNY_90-949', 'SNY_90-950', 'SNY_90-948', 'URR_708S', 'RTC_86907']
# ERROR: fid_truth_label: SNY_90-949 & top_5_labels_val_todos[i]: ['SNY_90-950', 'SNY_87-367', 'SNY_90-948', 'URR_795G', 'SBD_J795G']
# CORRECT: fid_truth_label: SNY_90-950 & top_5_labels_val_todos[i]: ['SNY_90-949', 'SNY_90-950', 'SNY_90-948', 'URR_708S', 'RTC_86907']
# ERROR: fid_truth_label: SNY_90-950 & top_5_labels_val_todos[i]: ['SNY_90-948', 'SNY_90-949', 'RTC_86907', 'IRW_BM2078612', 'IRW_BM2078608']
# ERROR: fid_truth_label: URR_708S & top_5_labels_val_todos[i]: ['SNY_87-471', 'IRW_BM2078610', 'SNY_87-369', 'SNY_87-473', 'PTY_J715S']
# CORRECT: fid_truth_label: URR_708S & top_5_labels_val_todos[i]: ['URR_708S', 'PTY_J715S', 'SNY_87-471', 'SNY_87-369', 'PTY_J712S']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_val_todos[i]: ['URR_795G', 'SNY_87-471', 'SNY_87-367', 'SBD_J795G', 'PTY_J715S']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_val_todos[i]: ['URR_795G', 'SNY_87-471', 'SNY_87-367', 'SBD_J795G', 'PTY_J715S']
#
# ____________________________ FINAL RESULTS_____________________
# top-5 val errors: 10 wrong out of 58 predictions, or 82.7586% accuracy

# %% [markdown]
# ### Part 2.3.2 Evaluate the New Fully-Connected Model on test Images

# %%
# reload the same integrated model architecture
with open('my_model_Step1.json', 'r') as model_json:
  json_file = model_json.read()
my_model = model_from_json(json_file)

# %%
# load weights from best trial with some stochasticitty/volatility over a handful of trials (v4 better results)
my_model.load_weights(top_model_weights_best)    # THIS SHOULD BE CHANGED BACK TO "model_flatten_weights.h5"

# %%
# compile that model with the same parameters used to build it (above)
my_model.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# create an ImageDataGenerator to read the test images in from images/test
batch_size = 29
test_features = np.zeros(shape=(test_cnt, 7, 7, 512))
test_labels = np.zeros(shape=(test_cnt,n_classes))

test_datagen = ImageDataGenerator(rescale=1. / 255,
                                        #zca_whitening=True,
                                        #shear_range=0.2,
                                        #zoom_range=0.2,
                                        #horizontal_flip=True,
                                        preprocessing_function = preprocess_input_BGR)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height_req, img_width_req),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 29 images belonging to 29 classes.

# %%
#evaluate my_model against test set
(test_loss, test_accuracy) = my_model.evaluate_generator(generator=test_generator,
                              steps=batch_size,
                              verbose=1)
# Out:
# 29/29 [==============================] - 10s 347ms/step

# %%
print('The ultimate TESTING Accuracy was {:.4f}%'.format(test_accuracy * 100))
print('The ultimate TESTING Loss was {}'.format(test_loss))
# Out:
# The ultimate TESTING Accuracy was 62.0690%
# The ultimate TESTING Loss was 1.2821252346038818

# %%
# # First obtain the predictions & related data from the weighted graph generated with the VGG16 topped model
prediction_probs_test = my_model.predict_generator(test_generator)
fids_ground_truth_test = test_generator.filenames
label_to_idx_test_dict =  test_generator.class_indices
idx_to_label_test_dict = dict((label, idx) for idx, label in label_to_idx_test_dict.items())

# %%
# Calculate the top-1 accuracy rate inputs
top_1_idxs_test_todos, top_1_labels_test_todos = get_top_n_idxs_and_labels(prediction_probs_test, idx_to_label_test_dict, 1)

# %%
# calculate the 1% accuracy rate in light of non-read files (test only)
i = 0
error_count_1_test = 0

for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_test):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label != top_1_labels_test_todos[i][0]:
      print('ERROR: fid_truth_label: {} & top_1_labels_test_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_test_todos[i][0]))
      error_count_1_test += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_1_labels_test_todos[i][0]: {}'.format(fid_truth_label, top_1_labels_test_todos[i][0]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-1 test errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_1_test, i, (1 - (error_count_1_test)/i)*100))
# Out:
# ERROR: fid_truth_label: IRW_BM2078606 & top_1_labels_test_todos[i][0]: IRW_BM2078608
# CORRECT: fid_truth_label: IRW_BM2078608 & top_1_labels_test_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078610 & top_1_labels_test_todos[i][0]: IRW_BM2078608
# ERROR: fid_truth_label: IRW_BM2078612 & top_1_labels_test_todos[i][0]: IRW_BM2078608
# CORRECT: fid_truth_label: IRW_BM2078700 & top_1_labels_test_todos[i][0]: IRW_BM2078700
# CORRECT: fid_truth_label: IRW_BM2078706 & top_1_labels_test_todos[i][0]: IRW_BM2078706
# CORRECT: fid_truth_label: KTI_3239 & top_1_labels_test_todos[i][0]: KTI_3239
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_1_labels_test_todos[i][0]: PTY_FA-113-8TAVSE
# ERROR: fid_truth_label: PTY_J708L & top_1_labels_test_todos[i][0]: RTC_86917
# ERROR: fid_truth_label: PTY_J708S & top_1_labels_test_todos[i][0]: PTY_J712S
# CORRECT: fid_truth_label: PTY_J712S & top_1_labels_test_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: PTY_J715S & top_1_labels_test_todos[i][0]: PTY_J712S
# ERROR: fid_truth_label: RTC_86907 & top_1_labels_test_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: RTC_86917 & top_1_labels_test_todos[i][0]: RTC_86917
# CORRECT: fid_truth_label: RTC_86922 & top_1_labels_test_todos[i][0]: RTC_86922
# CORRECT: fid_truth_label: RTC_86927 & top_1_labels_test_todos[i][0]: RTC_86927
# CORRECT: fid_truth_label: SBD_J795G & top_1_labels_test_todos[i][0]: SBD_J795G
# CORRECT: fid_truth_label: SBD_J795S & top_1_labels_test_todos[i][0]: SBD_J795S
# CORRECT: fid_truth_label: SNY_85-610 & top_1_labels_test_todos[i][0]: SNY_85-610
# CORRECT: fid_truth_label: SNY_85-762 & top_1_labels_test_todos[i][0]: SNY_85-762
# ERROR: fid_truth_label: SNY_87-367 & top_1_labels_test_todos[i][0]: SNY_87-473
# CORRECT: fid_truth_label: SNY_87-369 & top_1_labels_test_todos[i][0]: SNY_87-369
# ERROR: fid_truth_label: SNY_87-471 & top_1_labels_test_todos[i][0]: SNY_87-473
# ERROR: fid_truth_label: SNY_87-473 & top_1_labels_test_todos[i][0]: SNY_87-471
# ERROR: fid_truth_label: SNY_90-948 & top_1_labels_test_todos[i][0]: SNY_90-950
# CORRECT: fid_truth_label: SNY_90-949 & top_1_labels_test_todos[i][0]: SNY_90-949
# CORRECT: fid_truth_label: SNY_90-950 & top_1_labels_test_todos[i][0]: SNY_90-950
# CORRECT: fid_truth_label: URR_708S & top_1_labels_test_todos[i][0]: URR_708S
# CORRECT: fid_truth_label: URR_795G & top_1_labels_test_todos[i][0]: URR_795G
#
# ____________________________ FINAL RESULTS_____________________
# top-1 test errors: 11 wrong out of 29 predictions, or 62.0690% accuracy

# %%
# calculate the top-5 accuracy rate inputs
top_5_idxs_test_todos, top_5_labels_test_todos = get_top_n_idxs_and_labels(prediction_probs_test, idx_to_label_test_dict, 5)

# %%
# calculate the 5% accuracy rate in light of non-read files (test only)
i = 0
error_count_5_test = 0

for fid_ground_truth_idx, label_truth in enumerate(fids_ground_truth_test):
  fid_truth_label, fid_truth_name = label_truth.split('/')[0], label_truth.split('/')[0][1]
  if (fid_ground_truth_idx != 0) and ((fid_ground_truth_idx % 2 == 0 and fid_truth_label == 
    fid_ground_truth_prior) or (fid_ground_truth_idx % 2 != 1 and fid_truth_label == fid_ground_truth_prior)):
    print('Skipping - fid_ground_truth_idx: {}, fid_ground_truth_prior: {}, &  fid_truth_label: {}'.format(fid_ground_truth_idx, fid_ground_truth_prior, fid_truth_label))
    fid_ground_truth_prior = fid_truth_label
    i += 1
    continue
  else:
    fid_ground_truth_prior = fid_truth_label
    if fid_truth_label not in top_5_labels_test_todos[i]:
      print('ERROR: fid_truth_label: {} & top_5_labels_test_todos[i]: {}'.format(fid_truth_label, top_5_labels_test_todos[i]))
      error_count_5_test += 1
      i+= 1
    else:
      print('CORRECT: fid_truth_label: {} & top_5_labels_test_todos[i]: {}'.format(fid_truth_label, top_5_labels_test_todos[i]))
      i += 1

print("")
print("____________________________ FINAL RESULTS_____________________")
print('top-5 test errors: {} wrong out of {} predictions, or {:.4f}% accuracy'.format(error_count_5_test, i, (1 - (error_count_5_test)/i)*100))
# Out:
# CORRECT: fid_truth_label: IRW_BM2078606 & top_5_labels_test_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'IRW_BM2078700']
# CORRECT: fid_truth_label: IRW_BM2078608 & top_5_labels_test_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'IRW_BM2078700']
# CORRECT: fid_truth_label: IRW_BM2078610 & top_5_labels_test_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'IRW_BM2078700']
# CORRECT: fid_truth_label: IRW_BM2078612 & top_5_labels_test_todos[i]: ['IRW_BM2078608', 'IRW_BM2078612', 'IRW_BM2078610', 'IRW_BM2078606', 'IRW_BM2078700']
# CORRECT: fid_truth_label: IRW_BM2078700 & top_5_labels_test_todos[i]: ['IRW_BM2078700', 'SBD_J795G', 'IRW_BM2078608', 'SNY_90-950', 'IRW_BM2078606']
# CORRECT: fid_truth_label: IRW_BM2078706 & top_5_labels_test_todos[i]: ['IRW_BM2078706', 'SNY_85-762', 'SNY_87-369', 'RTC_86907', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: KTI_3239 & top_5_labels_test_todos[i]: ['KTI_3239', 'RTC_86927', 'RTC_86907', 'RTC_86922', 'SNY_85-762']
# CORRECT: fid_truth_label: PTY_FA-113-8TAVSE & top_5_labels_test_todos[i]: ['PTY_FA-113-8TAVSE', 'SBD_J795G', 'KTI_3239', 'SNY_90-948', 'IRW_BM2078706']
# CORRECT: fid_truth_label: PTY_J708L & top_5_labels_test_todos[i]: ['RTC_86917', 'PTY_J708L', 'SNY_87-473', 'RTC_86927', 'SNY_87-367']
# CORRECT: fid_truth_label: PTY_J708S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J715S', 'PTY_J708S', 'PTY_J708L', 'URR_708S']
# CORRECT: fid_truth_label: PTY_J712S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J715S', 'PTY_J708S', 'PTY_J708L', 'URR_708S']
# CORRECT: fid_truth_label: PTY_J715S & top_5_labels_test_todos[i]: ['PTY_J712S', 'PTY_J715S', 'PTY_J708S', 'PTY_J708L', 'URR_708S']
# CORRECT: fid_truth_label: RTC_86907 & top_5_labels_test_todos[i]: ['RTC_86927', 'RTC_86907', 'SNY_87-473', 'RTC_86917', 'RTC_86922']
# CORRECT: fid_truth_label: RTC_86917 & top_5_labels_test_todos[i]: ['RTC_86917', 'RTC_86927', 'RTC_86922', 'PTY_J708L', 'RTC_86907']
# CORRECT: fid_truth_label: RTC_86922 & top_5_labels_test_todos[i]: ['RTC_86922', 'RTC_86927', 'RTC_86907', 'RTC_86917', 'KTI_3239']
# CORRECT: fid_truth_label: RTC_86927 & top_5_labels_test_todos[i]: ['RTC_86927', 'RTC_86907', 'RTC_86917', 'RTC_86922', 'SNY_87-473']
# CORRECT: fid_truth_label: SBD_J795G & top_5_labels_test_todos[i]: ['SBD_J795G', 'SBD_J795S', 'URR_795G', 'PTY_FA-113-8TAVSE', 'SNY_85-762']
# CORRECT: fid_truth_label: SBD_J795S & top_5_labels_test_todos[i]: ['SBD_J795S', 'SBD_J795G', 'PTY_J708L', 'SNY_90-950', 'PTY_FA-113-8TAVSE']
# CORRECT: fid_truth_label: SNY_85-610 & top_5_labels_test_todos[i]: ['SNY_85-610', 'RTC_86922', 'RTC_86907', 'RTC_86917', 'RTC_86927']
# CORRECT: fid_truth_label: SNY_85-762 & top_5_labels_test_todos[i]: ['SNY_85-762', 'RTC_86927', 'KTI_3239', 'IRW_BM2078606', 'SNY_87-369']
# CORRECT: fid_truth_label: SNY_87-367 & top_5_labels_test_todos[i]: ['SNY_87-473', 'SNY_87-367', 'RTC_86917', 'RTC_86922', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_87-369 & top_5_labels_test_todos[i]: ['SNY_87-369', 'SNY_87-367', 'SNY_85-762', 'SNY_87-473', 'PTY_J712S']
# ERROR: fid_truth_label: SNY_87-471 & top_5_labels_test_todos[i]: ['SNY_87-473', 'RTC_86917', 'SNY_87-367', 'RTC_86927', 'RTC_86922']
# CORRECT: fid_truth_label: SNY_87-473 & top_5_labels_test_todos[i]: ['SNY_87-471', 'SNY_87-369', 'SNY_87-473', 'IRW_BM2078610', 'PTY_J715S']
# CORRECT: fid_truth_label: SNY_90-948 & top_5_labels_test_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'RTC_86907', 'URR_708S']
# CORRECT: fid_truth_label: SNY_90-949 & top_5_labels_test_todos[i]: ['SNY_90-949', 'SNY_90-950', 'SNY_90-948', 'URR_708S', 'RTC_86907']
# CORRECT: fid_truth_label: SNY_90-950 & top_5_labels_test_todos[i]: ['SNY_90-950', 'SNY_90-949', 'SNY_90-948', 'RTC_86907', 'RTC_86922']
# CORRECT: fid_truth_label: URR_708S & top_5_labels_test_todos[i]: ['URR_708S', 'PTY_J708L', 'PTY_J712S', 'PTY_J715S', 'KTI_3239']
# CORRECT: fid_truth_label: URR_795G & top_5_labels_test_todos[i]: ['URR_795G', 'SNY_87-471', 'SNY_87-367', 'PTY_J708S', 'PTY_J715S']
#
# ____________________________ FINAL RESULTS_____________________
# top-5 test errors: 1 wrong out of 29 predictions, or 96.5517% accuracy

# %% [markdown]
# ### Part 2.4 Test img input and return of top-5 best predictions

# %%
# choose, get, and view the image
fids_in = [fid for fid in os.listdir('.') if fid.endswith('.jpg')]
fids_sample = fids_in[0:9] 
imgs_sample = []
for fid in fids_sample:
  img = cv2.imread(fid)
  img = cv2.cv2.cvtColor(img, cv2.COLOR_RGB2BGR) # actually from BGR to RGB, but 1st & 3rd channel swap works 
  imgs_sample.append(img)

# %%
# Let's pick the 1st 9 sample images from this dir to view
plt.clf()
sample_cnt = 9
images_sample = imgs_sample
images_fids = fids_sample
plt.figure(figsize=(20,20))
plt.suptitle('The 1st 9 Sampled Images for This Dir in RGB', fontsize=30, weight='bold')

for i in range(sample_cnt):
    plt.subplot(331 + (i))
    plt.title(images_fids[i])
    plt.xticks([])
    plt.yticks([])   
    plt.imshow(imgs_sample[i])

plt.show()

# %%
# ready the image as a processable, predictable tensor
fid_in = fids_sample[1]
img_tensor = process_img_in(fid_in)

# %%
# get top-5 predictions
pred_probs = my_model.predict(img_tensor)
top_5_idxs, top_5_labels = get_top_n_idxs_and_labels(pred_probs, idx_to_label_test_dict, 5)
pred_labels_top5 = top_5_labels[0]
top_5_fids, top_5_imgs = get_top_5_matches(pred_labels_top5)

# %%
# Let's Look at those top-5 matches (hopefully)
plt.clf()
sample_cnt = 5
images_sample = top_5_imgs
images_fids = top_5_fids
# For each of the above pictures find the face bounding box
plt.figure(figsize=(20,20))
plt.suptitle('The Top-5 Matches for {}'.format(fid_in), fontsize=30, weight='bold')

for i in range(sample_cnt):
    plt.subplot(321 + (i))
    plt.title(images_fids[i])
    plt.xticks([])
    plt.yticks([])   
    plt.imshow(images_sample[i])

plt.show()

# %% [markdown]
# ## ON TO FINER SEQUENTIAL FINE-TUNING
